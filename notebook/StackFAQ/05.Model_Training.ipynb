# %% [markdown]
# **BERT-Finetuning with Triplet Loss**

# %%
# install required dependencies
# !pip3 install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading https://files.pythonhosted.org/packages/6a/e2/84d6acfcee2d83164149778a33b6bdd1a74e1bcb59b2b2cd1b861359b339/sentence-transformers-0.4.1.2.tar.gz (64kB)
#      |████████████████████████████████| 71kB 5.3MB/s
# Collecting transformers<5.0.0,>=3.1.0
#   Downloading https://files.pythonhosted.org/packages/f9/54/5ca07ec9569d2f232f3166de5457b63943882f7950ddfcc887732fc7fb23/transformers-4.3.3-py3-none-any.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 10.8MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.41.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.7.1+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.19.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.22.2.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.2.5)
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/f5/99/e0808cb947ba10f575839c43e8fafc9cc44e4a7a2c8f79c60db48220a577/sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 18.2MB/s
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 49.3MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/71/23/2ddc317b2121117bf34dd00f5b0de194158f2a44ee2bf5e47c7166878a97/tokenizers-0.10.1-cp37-cp37m-manylinux2010_x86_64.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 52.7MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers) (2019.12.20)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers) (20.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers) (3.0.12)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers) (3.7.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence-transformers) (3.7.4.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=3.1.0->sentence-transformers) (7.1.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers) (1.24.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers<5.0.0,>=3.1.0->sentence-transformers) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers<5.0.0,>=3.1.0->sentence-transformers) (3.4.0)
# Building wheels for collected packages: sentence-transformers, sacremoses
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-0.4.1.2-cp37-none-any.whl size=103068 sha256=0a69cbba8abebf4bd1615e57dbb6bb3290c82a1d6e65225142aa561e433af947
#   Stored in directory: /root/.cache/pip/wheels/3d/33/d1/5703dd56199c09d4a1b41e0c07fb4e7765a84d787cbdc48ac3
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp37-none-any.whl size=893262 sha256=ef45cd2e1c0623a98945a5373f98b7501267ab24c22abc7fbe9d441b217da8a6
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sentence-transformers sacremoses
# Installing collected packages: sacremoses, tokenizers, transformers, sentencepiece, sentence-transformers
# Successfully installed sacremoses-0.0.43 sentence-transformers-0.4.1.2 sentencepiece-0.1.95 tokenizers-0.10.1 transformers-4.3.3

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/BERT-FAQ
# Out:
# /content/drive/MyDrive/BERT-FAQ

# %%
# import required libraries
import pandas as pd
from faq_bert_finetuning import FAQ_BERT_Finetuning
from shared.utils import make_dirs

# %%
# define output path to save model & evaluation files
output_path = 'output/StackFAQ'
make_dirs(output_path)

# %% [markdown]
# **query_type=faq, neg_type="hard"**

# %%
# load hard_faq_dataset.csv
hard_faq_dataset = pd.read_csv('data/StackFAQ/dataset/triplet/faq/hard_faq_dataset.csv')
hard_faq_dataset
# Out:
#                                                 question  ...                                           negative
# 0                     Strikethrough with GitHub Markdown  ...  Simulated tops or vinyl roofs..can be cleaned ...
# 1                     Strikethrough with GitHub Markdown  ...  You said vinyl floor right, well don't use thi...
# 2                     Strikethrough with GitHub Markdown  ...  With extreme difficulty. Seek expert help. Jul...
# 3                     Strikethrough with GitHub Markdown  ...  My husband has installed crown in a room with ...
# 4                     Strikethrough with GitHub Markdown  ...  You need to wash the car thoroughly with soap ...
# ...                                                  ...  ...                                                ...
# 17251  How to create an em dash in Google Drive (Goog...  ...  FIREWALL OR FENDER GOOD LOCATIONS LET'S SEE MU...
# 17252  How to create an em dash in Google Drive (Goog...  ...  oops, your car just totaled it's self, sorry. ...
# 17253  How to create an em dash in Google Drive (Goog...  ...  with the e-brake. there no safe way to do it f...
# 17254  How to create an em dash in Google Drive (Goog...  ...  About the easiest way is to get the car in the...
# 17255  How to create an em dash in Google Drive (Goog...  ...  Oh good grief - the goverment is not going to ...
#
# [17256 rows x 3 columns]

# %%
# check dataset shape
hard_faq_dataset.shape
# Out:
# (17256, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_hard_faq = FAQ_BERT_Finetuning(
    loss_type="triplet", query_type='faq', neg_type='hard', version="1.1", epochs=3, batch_size=32, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_hard_faq.create_model(hard_faq_dataset, output_path)
# Out:
# 2021-02-27 18:21:11 - Lock 139625433431888 acquired on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=442.0, style=ProgressStyle(description_…
# 2021-02-27 18:21:11 - Lock 139625433431888 released on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# 2021-02-27 18:21:12 - Lock 139625433452816 acquired on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=267967963.0, style=ProgressStyle(descri…
# 2021-02-27 18:21:16 - Lock 139625433452816 released on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# 2021-02-27 18:21:18 - Lock 139625428745296 acquired on /root/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# 2021-02-27 18:21:19 - Lock 139625428745296 released on /root/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# 2021-02-27 18:21:19 - Lock 139625428744144 acquired on /root/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466062.0, style=ProgressStyle(descripti…
# 2021-02-27 18:21:19 - Lock 139625428744144 released on /root/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# 2021-02-27 18:21:19 - Use pytorch device: cuda
# 2021-02-27 18:21:19 - Generating directory structure
# 2021-02-27 18:21:19 - Generating triplets for training
# 2021-02-27 18:21:21 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=1.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=432.0, style=ProgressStyle(description_wi…
# 2021-02-27 18:26:36 - TripletEvaluator: Evaluating the model on val dataset after epoch 0:
# 2021-02-27 18:26:47 - Accuracy Cosine Distance:   	100.00
# 2021-02-27 18:26:47 - Accuracy Manhatten Distance:	100.00
# 2021-02-27 18:26:47 - Accuracy Euclidean Distance:	100.00
#
# 2021-02-27 18:26:47 - Save model to output/StackFAQv1.0/models/triplet_hard_faq_1.1
#
# 2021-02-27 18:26:49 - Evaluating model
# 2021-02-27 18:26:49 - Load pretrained SentenceTransformer: output/StackFAQv1.0/models/triplet_hard_faq_1.1
# 2021-02-27 18:26:49 - Load SentenceTransformer from folder: output/StackFAQv1.0/models/triplet_hard_faq_1.1
# 2021-02-27 18:26:50 - Use pytorch device: cuda
# 2021-02-27 18:26:50 - TripletEvaluator: Evaluating the model on test dataset:
# 2021-02-27 18:27:01 - Accuracy Cosine Distance:   	100.00
# 2021-02-27 18:27:01 - Accuracy Manhatten Distance:	100.00
# 2021-02-27 18:27:01 - Accuracy Euclidean Distance:	100.00

# %% [markdown]
# **query_type=faq, neg_type="simple"**

# %%
# load simple_faq_dataset.csv
simple_faq_dataset = pd.read_csv('data/StackFAQ/dataset/triplet/faq/simple_faq_dataset.csv')
simple_faq_dataset
# Out:
#                                                 question  ...                                           negative
# 0                     Strikethrough with GitHub Markdown  ...  It's possible that he is more active with you ...
# 1                     Strikethrough with GitHub Markdown  ...  Bitdeli provides a free badge that you can add...
# 2                     Strikethrough with GitHub Markdown  ...  I think @Oren has covered the functional aspec...
# 3                     Strikethrough with GitHub Markdown  ...  Just click and hold the letter label, starting...
# 4                     Strikethrough with GitHub Markdown  ...  For html / css / javascript, try http://jsfidd...
# ...                                                  ...  ...                                                ...
# 17251  How to create an em dash in Google Drive (Goog...  ...  If you are talking about searching, then @akir...
# 17252  How to create an em dash in Google Drive (Goog...  ...  I am actually almost certain it has to do with...
# 17253  How to create an em dash in Google Drive (Goog...  ...  gdocs2md does a good job of converting Google ...
# 17254  How to create an em dash in Google Drive (Goog...  ...  I have created an html5 application for this. ...
# 17255  How to create an em dash in Google Drive (Goog...  ...  We've built Paperpile to solve this problem: h...
#
# [17256 rows x 3 columns]

# %%
simple_faq_dataset.shape
# Out:
# (17256, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_simple_faq = FAQ_BERT_Finetuning(
    loss_type="triplet", query_type='faq', neg_type='simple', version="1.1", epochs=3, batch_size=32, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_simple_faq.create_model(simple_faq_dataset, output_path)
# Out:
# 2021-02-27 18:27:04 - Use pytorch device: cuda
# 2021-02-27 18:27:04 - Generating directory structure
# 2021-02-27 18:27:05 - Generating triplets for training
# 2021-02-27 18:27:06 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=1.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=432.0, style=ProgressStyle(description_wi…
# 2021-02-27 18:32:26 - TripletEvaluator: Evaluating the model on val dataset after epoch 0:
# 2021-02-27 18:32:37 - Accuracy Cosine Distance:   	98.84
# 2021-02-27 18:32:37 - Accuracy Manhatten Distance:	98.84
# 2021-02-27 18:32:37 - Accuracy Euclidean Distance:	98.84
#
# 2021-02-27 18:32:37 - Save model to output/StackFAQv1.0/models/triplet_simple_faq_1.1
#
# 2021-02-27 18:32:39 - Evaluating model
# 2021-02-27 18:32:39 - Load pretrained SentenceTransformer: output/StackFAQv1.0/models/triplet_simple_faq_1.1
# 2021-02-27 18:32:39 - Load SentenceTransformer from folder: output/StackFAQv1.0/models/triplet_simple_faq_1.1
# 2021-02-27 18:32:40 - Use pytorch device: cuda
# 2021-02-27 18:32:40 - TripletEvaluator: Evaluating the model on test dataset:
# 2021-02-27 18:32:51 - Accuracy Cosine Distance:   	99.25
# 2021-02-27 18:32:51 - Accuracy Manhatten Distance:	99.30
# 2021-02-27 18:32:51 - Accuracy Euclidean Distance:	99.25

# %% [markdown]
# **query_type=user_query, neg_type="hard"**

# %%
# load hard_user_query_dataset.csv
hard_user_query_dataset = pd.read_csv('data/StackFAQ/dataset/triplet/user_query/hard_user_query_dataset.csv')
hard_user_query_dataset
# Out:
#                                                  question  ...                                           negative
# 0               How to make font strikethrough on github.  ...  Use some rain-x on it.  you can buy it at an a...
# 1               How to make font strikethrough on github.  ...  u can use brake fluid to make it swell if it's...
# 2               How to make font strikethrough on github.  ...  change the oil and tune it up. unless it's die...
# 3               How to make font strikethrough on github.  ...  Fixing a leaky roof, especially something as t...
# 4               How to make font strikethrough on github.  ...  You can buy one of these...http://www.freedomf...
# ...                                                   ...  ...                                                ...
# 189027  How to create an em dash in Google Drive (Goog...  ...  FIREWALL OR FENDER GOOD LOCATIONS LET'S SEE MU...
# 189028  How to create an em dash in Google Drive (Goog...  ...  oops, your car just totaled it's self, sorry. ...
# 189029  How to create an em dash in Google Drive (Goog...  ...  with the e-brake. there no safe way to do it f...
# 189030  How to create an em dash in Google Drive (Goog...  ...  About the easiest way is to get the car in the...
# 189031  How to create an em dash in Google Drive (Goog...  ...  Oh good grief - the goverment is not going to ...
#
# [189032 rows x 3 columns]

# %%
hard_user_query_dataset.shape
# Out:
# (189032, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_hard_user_query = FAQ_BERT_Finetuning(
    loss_type="triplet", query_type='user_query', neg_type='hard', version="1.1", epochs=3, batch_size=32, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_hard_user_query.create_model(hard_user_query_dataset, output_path)
# Out:
# 2021-02-27 18:32:56 - Use pytorch device: cuda
# 2021-02-27 18:32:56 - Generating directory structure
# 2021-02-27 18:32:56 - Generating triplets for training
# 2021-02-27 18:33:10 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=1.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=4726.0, style=ProgressStyle(description_w…
# 2021-02-27 18:45:37 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 1000 steps:
# 2021-02-27 18:47:35 - Accuracy Cosine Distance:   	99.99
# 2021-02-27 18:47:35 - Accuracy Manhatten Distance:	99.99
# 2021-02-27 18:47:35 - Accuracy Euclidean Distance:	99.99
#
# 2021-02-27 18:47:35 - Save model to output/StackFAQv1.0/models/triplet_hard_user_query_1.1
# 2021-02-27 19:00:01 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 2000 steps:
# 2021-02-27 19:01:59 - Accuracy Cosine Distance:   	100.00
# 2021-02-27 19:01:59 - Accuracy Manhatten Distance:	100.00
# 2021-02-27 19:01:59 - Accuracy Euclidean Distance:	100.00
#
# 2021-02-27 19:01:59 - Save model to output/StackFAQv1.0/models/triplet_hard_user_query_1.1
# 2021-02-27 19:14:24 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 3000 steps:
# 2021-02-27 19:16:22 - Accuracy Cosine Distance:   	99.98
# 2021-02-27 19:16:22 - Accuracy Manhatten Distance:	99.98
# 2021-02-27 19:16:22 - Accuracy Euclidean Distance:	99.98
#
# 2021-02-27 19:28:46 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 4000 steps:
# 2021-02-27 19:30:44 - Accuracy Cosine Distance:   	100.00
# 2021-02-27 19:30:44 - Accuracy Manhatten Distance:	100.00
# 2021-02-27 19:30:44 - Accuracy Euclidean Distance:	100.00
#
#
# 2021-02-27 19:39:44 - TripletEvaluator: Evaluating the model on val dataset after epoch 0:
# 2021-02-27 19:41:42 - Accuracy Cosine Distance:   	100.00
# 2021-02-27 19:41:42 - Accuracy Manhatten Distance:	100.00
# 2021-02-27 19:41:42 - Accuracy Euclidean Distance:	100.00
#
#
# 2021-02-27 19:41:42 - Evaluating model
# 2021-02-27 19:41:42 - Load pretrained SentenceTransformer: output/StackFAQv1.0/models/triplet_hard_user_query_1.1
# 2021-02-27 19:41:42 - Load SentenceTransformer from folder: output/StackFAQv1.0/models/triplet_hard_user_query_1.1
# 2021-02-27 19:41:43 - Use pytorch device: cuda
# 2021-02-27 19:41:43 - TripletEvaluator: Evaluating the model on test dataset:
# 2021-02-27 19:43:41 - Accuracy Cosine Distance:   	100.00
# 2021-02-27 19:43:41 - Accuracy Manhatten Distance:	100.00
# 2021-02-27 19:43:41 - Accuracy Euclidean Distance:	100.00

# %% [markdown]
# **query_type=user_query, neg_type="simple"**

# %%
# load simple_user_query_dataset.csv
simple_user_query_dataset = pd.read_csv('data/StackFAQ/dataset/triplet/user_query/simple_user_query_dataset.csv')
simple_user_query_dataset
# Out:
#                                                  question  ...                                           negative
# 0               How to make font strikethrough on github.  ...  There is a really nasty way, i do often. In be...
# 1               How to make font strikethrough on github.  ...  Also note that Twitter does not retain an infi...
# 2               How to make font strikethrough on github.  ...  This might not be what you're looking for, but...
# 3               How to make font strikethrough on github.  ...  There is another workaround that does not requ...
# 4               How to make font strikethrough on github.  ...  Flickchart keeps track of the movies you've se...
# ...                                                   ...  ...                                                ...
# 172411  I require the longer (em) dash in google docs,...  ...  Note: @Joe has created a JavaScript bookmarkle...
# 172412  I require the longer (em) dash in google docs,...  ...  In Account Settings, there's a "Linked Account...
# 172413  I require the longer (em) dash in google docs,...  ...  Open the Conversion in the Standard View of GM...
# 172414  I require the longer (em) dash in google docs,...  ...  Insert > Special Characters...   Make sure you...
# 172415  I require the longer (em) dash in google docs,...  ...  I like doodle.com . It is simple and integrate...
#
# [172416 rows x 3 columns]

# %%
simple_user_query_dataset.shape
# Out:
# (172416, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_simple_user_query = FAQ_BERT_Finetuning(
    loss_type="triplet", query_type='user_query', neg_type='simple', version="1.1", epochs=3, batch_size=32, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_simple_user_query.create_model(simple_user_query_dataset, output_path)
# Out:
# 2021-02-27 19:43:50 - Use pytorch device: cuda
# 2021-02-27 19:43:50 - Generating directory structure
# 2021-02-27 19:43:50 - Generating triplets for training
# 2021-02-27 19:44:03 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=1.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=4311.0, style=ProgressStyle(description_w…
# 2021-02-27 19:56:46 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 1000 steps:
# 2021-02-27 19:58:30 - Accuracy Cosine Distance:   	98.94
# 2021-02-27 19:58:30 - Accuracy Manhatten Distance:	98.96
# 2021-02-27 19:58:30 - Accuracy Euclidean Distance:	98.96
#
# 2021-02-27 19:58:30 - Save model to output/StackFAQv1.0/models/triplet_simple_user_query_1.1
# 2021-02-27 20:11:03 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 2000 steps:
# 2021-02-27 20:12:47 - Accuracy Cosine Distance:   	99.26
# 2021-02-27 20:12:47 - Accuracy Manhatten Distance:	99.27
# 2021-02-27 20:12:47 - Accuracy Euclidean Distance:	99.27
#
# 2021-02-27 20:12:47 - Save model to output/StackFAQv1.0/models/triplet_simple_user_query_1.1
# 2021-02-27 20:25:18 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 3000 steps:
# 2021-02-27 20:27:02 - Accuracy Cosine Distance:   	99.34
# 2021-02-27 20:27:02 - Accuracy Manhatten Distance:	99.36
# 2021-02-27 20:27:02 - Accuracy Euclidean Distance:	99.37
#
# 2021-02-27 20:27:02 - Save model to output/StackFAQv1.0/models/triplet_simple_user_query_1.1
# 2021-02-27 20:39:32 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 4000 steps:
# 2021-02-27 20:41:16 - Accuracy Cosine Distance:   	99.35
# 2021-02-27 20:41:16 - Accuracy Manhatten Distance:	99.35
# 2021-02-27 20:41:16 - Accuracy Euclidean Distance:	99.35
#
#
# 2021-02-27 20:45:08 - TripletEvaluator: Evaluating the model on val dataset after epoch 0:
# 2021-02-27 20:46:52 - Accuracy Cosine Distance:   	99.36
# 2021-02-27 20:46:52 - Accuracy Manhatten Distance:	99.36
# 2021-02-27 20:46:52 - Accuracy Euclidean Distance:	99.35
#
#
# 2021-02-27 20:46:52 - Evaluating model
# 2021-02-27 20:46:52 - Load pretrained SentenceTransformer: output/StackFAQv1.0/models/triplet_simple_user_query_1.1
# 2021-02-27 20:46:52 - Load SentenceTransformer from folder: output/StackFAQv1.0/models/triplet_simple_user_query_1.1
# 2021-02-27 20:46:54 - Use pytorch device: cuda
# 2021-02-27 20:46:54 - TripletEvaluator: Evaluating the model on test dataset:
# 2021-02-27 20:48:37 - Accuracy Cosine Distance:   	99.28
# 2021-02-27 20:48:37 - Accuracy Manhatten Distance:	99.28
# 2021-02-27 20:48:37 - Accuracy Euclidean Distance:	99.28

# %% [markdown]
# **BERT-Finetuning with Softmax Loss**

# %% [markdown]
# **query_type=faq, neg_type="hard"**

# %%
# load hard_faq_dataset.csv
hard_faq_dataset = pd.read_csv('data/StackFAQ/dataset/softmax/faq/hard_faq_dataset.csv')
hard_faq_dataset
# Out:
#                                                 question  ... label
# 0              How to make font strikethrough on github.  ...     1
# 1      Is it possible to get  strikethrough letter fo...  ...     1
# 2                 Making the text on github crossed out.  ...     1
# 3      Introducing stikethrough formatting on markdow...  ...     1
# 4      The <s> tag for font on github markdown doesnt...  ...     1
# ...                                                  ...  ...   ...
# 10898  How to create an em dash in Google Drive (Goog...  ...     0
# 10899  How to create an em dash in Google Drive (Goog...  ...     0
# 10900  How to create an em dash in Google Drive (Goog...  ...     0
# 10901  How to create an em dash in Google Drive (Goog...  ...     0
# 10902  How to create an em dash in Google Drive (Goog...  ...     0
#
# [10903 rows x 3 columns]

# %%
# check dataset shape
hard_faq_dataset.shape
# Out:
# (10903, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_hard_faq = FAQ_BERT_Finetuning(
    loss_type="softmax", query_type='faq', neg_type='hard', version="1.1", epochs=3, batch_size=32, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_hard_faq.create_model(hard_faq_dataset, output_path)
# Out:
# 2021-02-27 21:02:23 - Lock 140464019202768 acquired on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=442.0, style=ProgressStyle(description_…
# 2021-02-27 21:02:23 - Lock 140464019202768 released on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# 2021-02-27 21:02:23 - Lock 140464019202768 acquired on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=267967963.0, style=ProgressStyle(descri…
# 2021-02-27 21:02:28 - Lock 140464019202768 released on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2021-02-27 21:02:30 - Lock 140462308121168 acquired on /root/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# 2021-02-27 21:02:30 - Lock 140462308121168 released on /root/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# 2021-02-27 21:02:30 - Lock 140462308121168 acquired on /root/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466062.0, style=ProgressStyle(descripti…
# 2021-02-27 21:02:31 - Lock 140462308121168 released on /root/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# 2021-02-27 21:02:31 - Use pytorch device: cuda
# 2021-02-27 21:02:31 - Generating directory structure
# 2021-02-27 21:02:31 - Generating triplets for training
# 2021-02-27 21:02:32 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=1.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=273.0, style=ProgressStyle(description_wi…
# 2021-02-27 21:08:24 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 0:
# 2021-02-27 21:08:40 - Accuracy:           100.00	(Threshold: 0.9416)
# 2021-02-27 21:08:40 - F1:                 100.00	(Threshold: 0.9416)
# 2021-02-27 21:08:40 - Precision:          100.00
# 2021-02-27 21:08:40 - Recall:             100.00
# 2021-02-27 21:08:40 - Average Precision:  100.00
#
# 2021-02-27 21:08:40 - Save model to output/StackFAQv1.0/models/softmax_hard_faq_1.1
#
# 2021-02-27 21:08:41 - Evaluating model
# 2021-02-27 21:08:43 - Use pytorch device: cuda
# 2021-02-27 21:08:43 - CEBinaryClassificationEvaluator: Evaluating the model on test dataset:
# 2021-02-27 21:08:59 - Accuracy:           99.82	(Threshold: 0.9752)
# 2021-02-27 21:08:59 - F1:                 99.88	(Threshold: 0.9752)
# 2021-02-27 21:08:59 - Precision:          99.76
# 2021-02-27 21:08:59 - Recall:             100.00
# 2021-02-27 21:08:59 - Average Precision:  99.99

# %% [markdown]
# **query_type=faq, neg_type="simple"**

# %%
# load simple_faq_dataset.csv
simple_faq_dataset = pd.read_csv('data/StackFAQ/dataset/softmax/faq/simple_faq_dataset.csv')
simple_faq_dataset
# Out:
#        label  ...                                             answer
# 0          1  ...                   Use ~~tildes around the words~~.
# 1          1  ...  I just used the following syntax  <del> ... </...
# 2          1  ...  from here :   Go here: http://www.facebook.com...
# 3          1  ...  Go to "Your Account".  Go to "Deactivate Accou...
# 4          1  ...  It is not neccessary to go through the deactiv...
# ...      ...  ...                                                ...
# 17970      0  ...  If you are talking about searching, then @akir...
# 17971      0  ...  I am actually almost certain it has to do with...
# 17972      0  ...  gdocs2md does a good job of converting Google ...
# 17973      0  ...  I have created an html5 application for this. ...
# 17974      0  ...  We've built Paperpile to solve this problem: h...
#
# [17975 rows x 3 columns]

# %%
simple_faq_dataset.shape
# Out:
# (17975, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_simple_faq = FAQ_BERT_Finetuning(
    loss_type="softmax", query_type='faq', neg_type='simple', version="1.1", epochs=3, batch_size=32, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_simple_faq.create_model(simple_faq_dataset, output_path)
# Out:
# 2021-02-27 21:18:49 - Lock 139873167099152 acquired on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=442.0, style=ProgressStyle(description_…
# 2021-02-27 21:18:50 - Lock 139873167099152 released on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# 2021-02-27 21:18:50 - Lock 139873300672272 acquired on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=267967963.0, style=ProgressStyle(descri…
# 2021-02-27 21:18:55 - Lock 139873300672272 released on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2021-02-27 21:18:57 - Lock 139873153868176 acquired on /root/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# 2021-02-27 21:18:57 - Lock 139873153868176 released on /root/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# 2021-02-27 21:18:58 - Lock 139873167253328 acquired on /root/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466062.0, style=ProgressStyle(descripti…
# 2021-02-27 21:18:58 - Lock 139873167253328 released on /root/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# 2021-02-27 21:18:58 - Use pytorch device: cuda
# 2021-02-27 21:18:58 - Generating directory structure
# 2021-02-27 21:18:58 - Generating triplets for training
# 2021-02-27 21:19:00 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=1.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=450.0, style=ProgressStyle(description_wi…
# 2021-02-27 21:28:58 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 0:
# 2021-02-27 21:29:27 - Accuracy:           96.44	(Threshold: 0.4508)
# 2021-02-27 21:29:27 - F1:                 51.09	(Threshold: 0.2633)
# 2021-02-27 21:29:27 - Precision:          54.69
# 2021-02-27 21:29:27 - Recall:             47.95
# 2021-02-27 21:29:27 - Average Precision:  41.72
#
# 2021-02-27 21:29:27 - Save model to output/StackFAQv1.0/models/softmax_simple_faq_1.1
#
# 2021-02-27 21:29:28 - Evaluating model
# 2021-02-27 21:29:30 - Use pytorch device: cuda
# 2021-02-27 21:29:30 - CEBinaryClassificationEvaluator: Evaluating the model on test dataset:
# 2021-02-27 21:29:57 - Accuracy:           96.33	(Threshold: 0.5268)
# 2021-02-27 21:29:57 - F1:                 51.46	(Threshold: 0.1112)
# 2021-02-27 21:29:57 - Precision:          44.90
# 2021-02-27 21:29:57 - Recall:             60.27
# 2021-02-27 21:29:57 - Average Precision:  47.34

# %% [markdown]
# **query_type=user_query, neg_type="hard"**

# %%
# load hard_user_query_dataset.csv
hard_user_query_dataset = pd.read_csv('data/StackFAQ/dataset/softmax/user_query/hard_user_query_dataset.csv')
hard_user_query_dataset
# Out:
#                                                 question  ... label
# 0              How to make font strikethrough on github.  ...     1
# 1      Is it possible to get  strikethrough letter fo...  ...     1
# 2                 Making the text on github crossed out.  ...     1
# 3      Introducing stikethrough formatting on markdow...  ...     1
# 4      The <s> tag for font on github markdown doesnt...  ...     1
# ...                                                  ...  ...   ...
# 40761  How to create an em dash in Google Drive (Goog...  ...     0
# 40762  How to create an em dash in Google Drive (Goog...  ...     0
# 40763  How to create an em dash in Google Drive (Goog...  ...     0
# 40764  How to create an em dash in Google Drive (Goog...  ...     0
# 40765  How to create an em dash in Google Drive (Goog...  ...     0
#
# [40766 rows x 3 columns]

# %%
hard_user_query_dataset.shape
# Out:
# (40766, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_hard_user_query = FAQ_BERT_Finetuning(
    loss_type="softmax", query_type='user_query', neg_type='hard', version="1.1", epochs=3, batch_size=32, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_hard_user_query.create_model(hard_user_query_dataset, output_path)
# Out:
# 2021-02-27 21:33:08 - Lock 139832747768656 acquired on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=442.0, style=ProgressStyle(description_…
# 2021-02-27 21:33:09 - Lock 139832747768656 released on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# 2021-02-27 21:33:09 - Lock 139831157376208 acquired on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=267967963.0, style=ProgressStyle(descri…
# 2021-02-27 21:33:14 - Lock 139831157376208 released on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2021-02-27 21:33:16 - Lock 139831020991760 acquired on /root/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# 2021-02-27 21:33:16 - Lock 139831020991760 released on /root/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# 2021-02-27 21:33:17 - Lock 139831020623696 acquired on /root/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466062.0, style=ProgressStyle(descripti…
# 2021-02-27 21:33:17 - Lock 139831020623696 released on /root/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# 2021-02-27 21:33:17 - Use pytorch device: cuda
# 2021-02-27 21:33:17 - Generating directory structure
# 2021-02-27 21:33:19 - Generating triplets for training
# 2021-02-27 21:33:22 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=1.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=1020.0, style=ProgressStyle(description_w…
# 2021-02-27 21:55:07 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset in epoch 0 after 1000 steps:
# 2021-02-27 21:56:10 - Accuracy:           100.00	(Threshold: 0.5673)
# 2021-02-27 21:56:10 - F1:                 100.00	(Threshold: 0.5673)
# 2021-02-27 21:56:10 - Precision:          100.00
# 2021-02-27 21:56:10 - Recall:             100.00
# 2021-02-27 21:56:10 - Average Precision:  100.00
#
# 2021-02-27 21:56:10 - Save model to output/StackFAQv1.0/models/softmax_hard_user_query_1.1
#
# 2021-02-27 21:56:36 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 0:
# 2021-02-27 21:57:39 - Accuracy:           100.00	(Threshold: 0.5726)
# 2021-02-27 21:57:39 - F1:                 100.00	(Threshold: 0.5726)
# 2021-02-27 21:57:39 - Precision:          100.00
# 2021-02-27 21:57:39 - Recall:             100.00
# 2021-02-27 21:57:39 - Average Precision:  100.00
#
#
# 2021-02-27 21:57:39 - Evaluating model
# 2021-02-27 21:57:41 - Use pytorch device: cuda
# 2021-02-27 21:57:41 - CEBinaryClassificationEvaluator: Evaluating the model on test dataset:
# 2021-02-27 21:58:43 - Accuracy:           100.00	(Threshold: 0.4074)
# 2021-02-27 21:58:43 - F1:                 100.00	(Threshold: 0.4074)
# 2021-02-27 21:58:43 - Precision:          100.00
# 2021-02-27 21:58:43 - Recall:             100.00
# 2021-02-27 21:58:43 - Average Precision:  100.00

# %% [markdown]
# **query_type=user_query, neg_type="simple"**

# %%
# load simple_user_query_dataset.csv
simple_user_query_dataset = pd.read_csv('data/StackFAQ/dataset/softmax/user_query/simple_user_query_dataset.csv')
simple_user_query_dataset
# Out:
#         label  ...                                             answer
# 0           1  ...                   Use ~~tildes around the words~~.
# 1           1  ...                   Use ~~tildes around the words~~.
# 2           1  ...                   Use ~~tildes around the words~~.
# 3           1  ...                   Use ~~tildes around the words~~.
# 4           1  ...                   Use ~~tildes around the words~~.
# ...       ...  ...                                                ...
# 179595      0  ...  Note: @Joe has created a JavaScript bookmarkle...
# 179596      0  ...  In Account Settings, there's a "Linked Account...
# 179597      0  ...  Open the Conversion in the Standard View of GM...
# 179598      0  ...  Insert > Special Characters...   Make sure you...
# 179599      0  ...  I like doodle.com . It is simple and integrate...
#
# [179600 rows x 3 columns]

# %%
simple_user_query_dataset.shape
# Out:
# (179600, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_simple_user_query = FAQ_BERT_Finetuning(
    loss_type="softmax", query_type='user_query', neg_type='simple', version="1.1", epochs=3, batch_size=32, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_simple_user_query.create_model(simple_user_query_dataset, output_path)
# Out:
# 2021-02-27 22:00:35 - Lock 140685160714448 acquired on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=442.0, style=ProgressStyle(description_…
# 2021-02-27 22:00:36 - Lock 140685160714448 released on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# 2021-02-27 22:00:36 - Lock 140685160676880 acquired on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=267967963.0, style=ProgressStyle(descri…
# 2021-02-27 22:00:41 - Lock 140685160676880 released on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2021-02-27 22:00:43 - Lock 140686886455696 acquired on /root/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# 2021-02-27 22:00:44 - Lock 140686886455696 released on /root/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# 2021-02-27 22:00:44 - Lock 140685159999568 acquired on /root/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466062.0, style=ProgressStyle(descripti…
# 2021-02-27 22:00:44 - Lock 140685159999568 released on /root/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# 2021-02-27 22:00:44 - Use pytorch device: cuda
# 2021-02-27 22:00:44 - Generating directory structure
# 2021-02-27 22:00:45 - Generating triplets for training
# 2021-02-27 22:00:58 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=1.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=4490.0, style=ProgressStyle(description_w…
# 2021-02-27 22:23:48 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset in epoch 0 after 1000 steps:
# 2021-02-27 22:28:19 - Accuracy:           96.09	(Threshold: 0.0348)
# 2021-02-27 22:28:19 - F1:                 7.76	(Threshold: 0.0319)
# 2021-02-27 22:28:19 - Precision:          4.07
# 2021-02-27 22:28:19 - Recall:             83.88
# 2021-02-27 22:28:19 - Average Precision:  4.53
#
# 2021-02-27 22:28:19 - Save model to output/StackFAQv1.0/models/softmax_simple_user_query_1.1
# 2021-02-27 22:50:57 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset in epoch 0 after 2000 steps:
# 2021-02-27 22:55:29 - Accuracy:           96.24	(Threshold: 0.0420)
# 2021-02-27 22:55:29 - F1:                 36.94	(Threshold: 0.0366)
# 2021-02-27 22:55:29 - Precision:          35.17
# 2021-02-27 22:55:29 - Recall:             38.90
# 2021-02-27 22:55:29 - Average Precision:  27.75
#
# 2021-02-27 22:55:30 - Save model to output/StackFAQv1.0/models/softmax_simple_user_query_1.1
# 2021-02-27 23:17:59 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset in epoch 0 after 3000 steps:
# 2021-02-27 23:22:33 - Accuracy:           96.56	(Threshold: 0.4926)
# 2021-02-27 23:22:33 - F1:                 48.83	(Threshold: 0.2027)
# 2021-02-27 23:22:33 - Precision:          47.40
# 2021-02-27 23:22:33 - Recall:             50.35
# 2021-02-27 23:22:33 - Average Precision:  44.57
#
# 2021-02-27 23:22:33 - Save model to output/StackFAQv1.0/models/softmax_simple_user_query_1.1
# 2021-02-27 23:45:21 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset in epoch 0 after 4000 steps:
# 2021-02-27 23:49:53 - Accuracy:           96.66	(Threshold: 0.5075)
# 2021-02-27 23:49:53 - F1:                 53.32	(Threshold: 0.1260)
# 2021-02-27 23:49:53 - Precision:          46.79
# 2021-02-27 23:49:53 - Recall:             61.95
# 2021-02-27 23:49:53 - Average Precision:  49.20
#
# 2021-02-27 23:49:53 - Save model to output/StackFAQv1.0/models/softmax_simple_user_query_1.1
#
# 2021-02-28 00:01:13 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 0:
# 2021-02-28 00:05:47 - Accuracy:           96.68	(Threshold: 0.5923)
# 2021-02-28 00:05:47 - F1:                 54.27	(Threshold: 0.1357)
# 2021-02-28 00:05:47 - Precision:          47.00
# 2021-02-28 00:05:47 - Recall:             64.21
# 2021-02-28 00:05:47 - Average Precision:  49.62
#
# 2021-02-28 00:05:47 - Save model to output/StackFAQv1.0/models/softmax_simple_user_query_1.1
#
# 2021-02-28 00:05:48 - Evaluating model
# 2021-02-28 00:05:50 - Use pytorch device: cuda
# 2021-02-28 00:05:50 - CEBinaryClassificationEvaluator: Evaluating the model on test dataset:
# 2021-02-28 00:10:32 - Accuracy:           96.75	(Threshold: 0.5546)
# 2021-02-28 00:10:32 - F1:                 54.55	(Threshold: 0.2720)
# 2021-02-28 00:10:32 - Precision:          53.21
# 2021-02-28 00:10:32 - Recall:             55.95
# 2021-02-28 00:10:32 - Average Precision:  49.90
