# %% [markdown]
# **BERT-Finetuning with Triplet Loss**

# %%
# install required dependencies
# !pip3 install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading https://files.pythonhosted.org/packages/6a/e2/84d6acfcee2d83164149778a33b6bdd1a74e1bcb59b2b2cd1b861359b339/sentence-transformers-0.4.1.2.tar.gz (64kB)
#      |████████████████████████████████| 71kB 5.9MB/s
# Collecting transformers<5.0.0,>=3.1.0
#   Downloading https://files.pythonhosted.org/packages/f9/54/5ca07ec9569d2f232f3166de5457b63943882f7950ddfcc887732fc7fb23/transformers-4.3.3-py3-none-any.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 15.7MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.41.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.7.1+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.19.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.22.2.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.2.5)
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/f5/99/e0808cb947ba10f575839c43e8fafc9cc44e4a7a2c8f79c60db48220a577/sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 37.2MB/s
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers) (3.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers) (3.0.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers) (2.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers) (20.9)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/71/23/2ddc317b2121117bf34dd00f5b0de194158f2a44ee2bf5e47c7166878a97/tokenizers-0.10.1-cp37-cp37m-manylinux2010_x86_64.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 31.8MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers) (2019.12.20)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 39.6MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence-transformers) (3.7.4.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers<5.0.0,>=3.1.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers) (2.10)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers<5.0.0,>=3.1.0->sentence-transformers) (2.4.7)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=3.1.0->sentence-transformers) (7.1.2)
# Building wheels for collected packages: sentence-transformers, sacremoses
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-0.4.1.2-cp37-none-any.whl size=103068 sha256=3101cec355562e11854dcb82512a63cd55b2edd1a8407f934dc4afd7ee5013bf
#   Stored in directory: /root/.cache/pip/wheels/3d/33/d1/5703dd56199c09d4a1b41e0c07fb4e7765a84d787cbdc48ac3
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp37-none-any.whl size=893262 sha256=bd5c95f5a75ff9da1334b5becf85a5feaac01829a564ba700e8c8f38e0094dc8
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sentence-transformers sacremoses
# Installing collected packages: tokenizers, sacremoses, transformers, sentencepiece, sentence-transformers
# Successfully installed sacremoses-0.0.43 sentence-transformers-0.4.1.2 sentencepiece-0.1.95 tokenizers-0.10.1 transformers-4.3.3

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/BERT-FAQ
# Out:
# /content/drive/MyDrive/BERT-FAQ

# %%
# import required libraries
import pandas as pd
from faq_bert_finetuning import FAQ_BERT_Finetuning
from shared.utils import make_dirs

# %%
# define output path to save model & evaluation files
output_path = 'output/StackFAQ'
make_dirs(output_path)

# %% [markdown]
# **query_type=faq, neg_type="hard"**

# %%
# load hard_faq_dataset.csv
hard_faq_dataset = pd.read_csv('data/StackFAQ/dataset/triplet/faq/hard_faq_dataset.csv')
hard_faq_dataset
# Out:
#                                                 question  ...                                           negative
# 0                     Strikethrough with GitHub Markdown  ...  Markdown Here  I've been using Markdown Here f...
# 1                     Strikethrough with GitHub Markdown  ...  There is a Google Chrome extension called stri...
# 2                     Strikethrough with GitHub Markdown  ...  BitDeli had a solution for this, based on a ba...
# 3                     Strikethrough with GitHub Markdown  ...  Also try Markdown Editor , that supports integ...
# 4                     Strikethrough with GitHub Markdown  ...  This extension works in Firefox!!!  strikeThrough
# ...                                                  ...  ...                                                ...
# 17251  How to create an em dash in Google Drive (Goog...  ...  It is possible to use the API to search all fi...
# 17252  How to create an em dash in Google Drive (Goog...  ...  I faced this problem too, and I didn't want to...
# 17253  How to create an em dash in Google Drive (Goog...  ...  Just to be clear for rookies like me,  No, the...
# 17254  How to create an em dash in Google Drive (Goog...  ...  I agree with the previous answer in that you c...
# 17255  How to create an em dash in Google Drive (Goog...  ...  If you know the email addresses of the people ...
#
# [17256 rows x 3 columns]

# %%
# check dataset shape
hard_faq_dataset.shape
# Out:
# (17256, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_hard_faq = FAQ_BERT_Finetuning(
    loss_type="triplet", query_type='faq', neg_type='hard', version="1.1", epochs=4, batch_size=16, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_hard_faq.create_model(hard_faq_dataset, output_path)
# Out:
# 2021-03-03 10:46:17 - Lock 139669859856720 acquired on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=442.0, style=ProgressStyle(description_…
# 2021-03-03 10:46:18 - Lock 139669859856720 released on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# 2021-03-03 10:46:18 - Lock 139669859879184 acquired on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=267967963.0, style=ProgressStyle(descri…
# 2021-03-03 10:46:23 - Lock 139669859879184 released on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# 2021-03-03 10:46:25 - Lock 139668267173968 acquired on /root/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# 2021-03-03 10:46:25 - Lock 139668267173968 released on /root/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# 2021-03-03 10:46:25 - Lock 139668128978768 acquired on /root/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466062.0, style=ProgressStyle(descripti…
# 2021-03-03 10:46:26 - Lock 139668128978768 released on /root/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# 2021-03-03 10:46:26 - Use pytorch device: cuda
# 2021-03-03 10:46:26 - Generating directory structure
# 2021-03-03 10:46:26 - Generating triplets for training
# 2021-03-03 10:46:27 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=4.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=863.0, style=ProgressStyle(description_wi…
# 2021-03-03 10:52:22 - TripletEvaluator: Evaluating the model on val dataset after epoch 0:
# 2021-03-03 10:52:33 - Accuracy Cosine Distance:   	99.83
# 2021-03-03 10:52:33 - Accuracy Manhatten Distance:	99.83
# 2021-03-03 10:52:33 - Accuracy Euclidean Distance:	99.83
#
# 2021-03-03 10:52:33 - Save model to output/StackFAQ/models/triplet_hard_faq_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=863.0, style=ProgressStyle(description_wi…
# 2021-03-03 10:58:15 - TripletEvaluator: Evaluating the model on val dataset after epoch 1:
# 2021-03-03 10:58:26 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 10:58:26 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 10:58:26 - Accuracy Euclidean Distance:	100.00
#
# 2021-03-03 10:58:26 - Save model to output/StackFAQ/models/triplet_hard_faq_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=863.0, style=ProgressStyle(description_wi…
# 2021-03-03 11:04:08 - TripletEvaluator: Evaluating the model on val dataset after epoch 2:
# 2021-03-03 11:04:19 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 11:04:19 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 11:04:19 - Accuracy Euclidean Distance:	100.00
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=863.0, style=ProgressStyle(description_wi…
# 2021-03-03 11:09:59 - TripletEvaluator: Evaluating the model on val dataset after epoch 3:
# 2021-03-03 11:10:10 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 11:10:10 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 11:10:10 - Accuracy Euclidean Distance:	100.00
#
#
# 2021-03-03 11:10:10 - Evaluating model
# 2021-03-03 11:10:10 - Load pretrained SentenceTransformer: output/StackFAQ/models/triplet_hard_faq_1.1
# 2021-03-03 11:10:10 - Load SentenceTransformer from folder: output/StackFAQ/models/triplet_hard_faq_1.1
# 2021-03-03 11:10:11 - Use pytorch device: cuda
# 2021-03-03 11:10:11 - TripletEvaluator: Evaluating the model on test dataset:
# 2021-03-03 11:10:22 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 11:10:22 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 11:10:22 - Accuracy Euclidean Distance:	100.00

# %% [markdown]
# **query_type=faq, neg_type="simple"**

# %%
# load simple_faq_dataset.csv
simple_faq_dataset = pd.read_csv('data/StackFAQ/dataset/triplet/faq/simple_faq_dataset.csv')
simple_faq_dataset
# Out:
#                                                 question  ...                                           negative
# 0                     Strikethrough with GitHub Markdown  ...  It's possible that he is more active with you ...
# 1                     Strikethrough with GitHub Markdown  ...  Bitdeli provides a free badge that you can add...
# 2                     Strikethrough with GitHub Markdown  ...  I think @Oren has covered the functional aspec...
# 3                     Strikethrough with GitHub Markdown  ...  Just click and hold the letter label, starting...
# 4                     Strikethrough with GitHub Markdown  ...  For html / css / javascript, try http://jsfidd...
# ...                                                  ...  ...                                                ...
# 17251  How to create an em dash in Google Drive (Goog...  ...  If you are talking about searching, then @akir...
# 17252  How to create an em dash in Google Drive (Goog...  ...  I am actually almost certain it has to do with...
# 17253  How to create an em dash in Google Drive (Goog...  ...  gdocs2md does a good job of converting Google ...
# 17254  How to create an em dash in Google Drive (Goog...  ...  I have created an html5 application for this. ...
# 17255  How to create an em dash in Google Drive (Goog...  ...  We've built Paperpile to solve this problem: h...
#
# [17256 rows x 3 columns]

# %%
simple_faq_dataset.shape
# Out:
# (17256, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_simple_faq = FAQ_BERT_Finetuning(
    loss_type="triplet", query_type='faq', neg_type='simple', version="1.1", epochs=4, batch_size=16, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_simple_faq.create_model(simple_faq_dataset, output_path)
# Out:
# 2021-03-03 11:12:59 - Use pytorch device: cuda
# 2021-03-03 11:12:59 - Generating directory structure
# 2021-03-03 11:12:59 - Generating triplets for training
# 2021-03-03 11:13:00 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=4.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=863.0, style=ProgressStyle(description_wi…
# 2021-03-03 11:18:48 - TripletEvaluator: Evaluating the model on val dataset after epoch 0:
# 2021-03-03 11:18:58 - Accuracy Cosine Distance:   	99.02
# 2021-03-03 11:18:58 - Accuracy Manhatten Distance:	99.02
# 2021-03-03 11:18:58 - Accuracy Euclidean Distance:	99.02
#
# 2021-03-03 11:18:58 - Save model to output/StackFAQ/models/triplet_simple_faq_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=863.0, style=ProgressStyle(description_wi…
# 2021-03-03 11:24:42 - TripletEvaluator: Evaluating the model on val dataset after epoch 1:
# 2021-03-03 11:24:53 - Accuracy Cosine Distance:   	99.48
# 2021-03-03 11:24:53 - Accuracy Manhatten Distance:	99.48
# 2021-03-03 11:24:53 - Accuracy Euclidean Distance:	99.48
#
# 2021-03-03 11:24:53 - Save model to output/StackFAQ/models/triplet_simple_faq_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=863.0, style=ProgressStyle(description_wi…
# 2021-03-03 11:30:36 - TripletEvaluator: Evaluating the model on val dataset after epoch 2:
# 2021-03-03 11:30:47 - Accuracy Cosine Distance:   	99.42
# 2021-03-03 11:30:47 - Accuracy Manhatten Distance:	99.42
# 2021-03-03 11:30:47 - Accuracy Euclidean Distance:	99.42
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=863.0, style=ProgressStyle(description_wi…
# 2021-03-03 11:36:28 - TripletEvaluator: Evaluating the model on val dataset after epoch 3:
# 2021-03-03 11:36:39 - Accuracy Cosine Distance:   	99.42
# 2021-03-03 11:36:39 - Accuracy Manhatten Distance:	99.42
# 2021-03-03 11:36:39 - Accuracy Euclidean Distance:	99.42
#
#
# 2021-03-03 11:36:39 - Evaluating model
# 2021-03-03 11:36:39 - Load pretrained SentenceTransformer: output/StackFAQ/models/triplet_simple_faq_1.1
# 2021-03-03 11:36:39 - Load SentenceTransformer from folder: output/StackFAQ/models/triplet_simple_faq_1.1
# 2021-03-03 11:36:40 - Use pytorch device: cuda
# 2021-03-03 11:36:40 - TripletEvaluator: Evaluating the model on test dataset:
# 2021-03-03 11:36:51 - Accuracy Cosine Distance:   	99.30
# 2021-03-03 11:36:51 - Accuracy Manhatten Distance:	99.30
# 2021-03-03 11:36:51 - Accuracy Euclidean Distance:	99.30

# %% [markdown]
# **query_type=user_query, neg_type="hard"**

# %%
# load hard_user_query_dataset.csv
hard_user_query_dataset = pd.read_csv('data/StackFAQ/dataset/triplet/user_query/hard_user_query_dataset.csv')
hard_user_query_dataset
# Out:
#                                                  question  ...                                           negative
# 0               How to make font strikethrough on github.  ...  One feature that I's miss from google document...
# 1               How to make font strikethrough on github.  ...  There is a Google Chrome extension called stri...
# 2               How to make font strikethrough on github.  ...  This extension works in Firefox!!!  strikeThrough
# 3               How to make font strikethrough on github.  ...  You can make use of the the question or answer...
# 4               How to make font strikethrough on github.  ...  There is no native way to do it, so you either...
# ...                                                   ...  ...                                                ...
# 189507  How to create an em dash in Google Drive (Goog...  ...  It is possible to use the API to search all fi...
# 189508  How to create an em dash in Google Drive (Goog...  ...  I faced this problem too, and I didn't want to...
# 189509  How to create an em dash in Google Drive (Goog...  ...  Just to be clear for rookies like me,  No, the...
# 189510  How to create an em dash in Google Drive (Goog...  ...  I agree with the previous answer in that you c...
# 189511  How to create an em dash in Google Drive (Goog...  ...  If you know the email addresses of the people ...
#
# [189512 rows x 3 columns]

# %%
hard_user_query_dataset.shape
# Out:
# (189512, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_hard_user_query = FAQ_BERT_Finetuning(
    loss_type="triplet", query_type='user_query', neg_type='hard', version="1.1", epochs=4, batch_size=16, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_hard_user_query.create_model(hard_user_query_dataset, output_path)
# Out:
# 2021-03-03 14:04:41 - Lock 140106228403856 acquired on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=442.0, style=ProgressStyle(description_…
# 2021-03-03 14:04:41 - Lock 140106228403856 released on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# 2021-03-03 14:04:41 - Lock 140106094622864 acquired on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=267967963.0, style=ProgressStyle(descri…
# 2021-03-03 14:04:46 - Lock 140106094622864 released on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# 2021-03-03 14:04:47 - Lock 140106081370064 acquired on /root/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# 2021-03-03 14:04:47 - Lock 140106081370064 released on /root/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# 2021-03-03 14:04:47 - Lock 140106089913296 acquired on /root/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466062.0, style=ProgressStyle(descripti…
# 2021-03-03 14:04:47 - Lock 140106089913296 released on /root/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# 2021-03-03 14:04:47 - Use pytorch device: cuda
# 2021-03-03 14:04:47 - Generating directory structure
# 2021-03-03 14:04:47 - Generating triplets for training
# 2021-03-03 14:05:02 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=4.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=9476.0, style=ProgressStyle(description_w…
# 2021-03-03 14:12:09 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 1000 steps:
# 2021-03-03 14:14:10 - Accuracy Cosine Distance:   	92.96
# 2021-03-03 14:14:10 - Accuracy Manhatten Distance:	93.24
# 2021-03-03 14:14:10 - Accuracy Euclidean Distance:	93.26
#
# 2021-03-03 14:14:10 - Save model to output/StackFAQ/models/triplet_hard_user_query_1.1
# 2021-03-03 14:21:03 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 2000 steps:
# 2021-03-03 14:23:05 - Accuracy Cosine Distance:   	98.58
# 2021-03-03 14:23:05 - Accuracy Manhatten Distance:	98.56
# 2021-03-03 14:23:05 - Accuracy Euclidean Distance:	98.59
#
# 2021-03-03 14:23:05 - Save model to output/StackFAQ/models/triplet_hard_user_query_1.1
# 2021-03-03 14:29:53 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 3000 steps:
# 2021-03-03 14:31:54 - Accuracy Cosine Distance:   	99.64
# 2021-03-03 14:31:54 - Accuracy Manhatten Distance:	99.65
# 2021-03-03 14:31:54 - Accuracy Euclidean Distance:	99.65
#
# 2021-03-03 14:31:54 - Save model to output/StackFAQ/models/triplet_hard_user_query_1.1
# 2021-03-03 14:38:40 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 4000 steps:
# 2021-03-03 14:40:41 - Accuracy Cosine Distance:   	99.73
# 2021-03-03 14:40:41 - Accuracy Manhatten Distance:	99.73
# 2021-03-03 14:40:41 - Accuracy Euclidean Distance:	99.74
#
# 2021-03-03 14:40:41 - Save model to output/StackFAQ/models/triplet_hard_user_query_1.1
# 2021-03-03 14:47:26 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 5000 steps:
# 2021-03-03 14:49:27 - Accuracy Cosine Distance:   	99.81
# 2021-03-03 14:49:27 - Accuracy Manhatten Distance:	99.81
# 2021-03-03 14:49:27 - Accuracy Euclidean Distance:	99.82
#
# 2021-03-03 14:49:27 - Save model to output/StackFAQ/models/triplet_hard_user_query_1.1
# 2021-03-03 14:56:10 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 6000 steps:
# 2021-03-03 14:58:12 - Accuracy Cosine Distance:   	99.96
# 2021-03-03 14:58:12 - Accuracy Manhatten Distance:	99.97
# 2021-03-03 14:58:12 - Accuracy Euclidean Distance:	99.96
#
# 2021-03-03 14:58:12 - Save model to output/StackFAQ/models/triplet_hard_user_query_1.1
# 2021-03-03 15:04:54 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 7000 steps:
# 2021-03-03 15:06:56 - Accuracy Cosine Distance:   	99.96
# 2021-03-03 15:06:56 - Accuracy Manhatten Distance:	99.96
# 2021-03-03 15:06:56 - Accuracy Euclidean Distance:	99.96
#
# 2021-03-03 15:13:37 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 8000 steps:
# 2021-03-03 15:15:38 - Accuracy Cosine Distance:   	99.97
# 2021-03-03 15:15:38 - Accuracy Manhatten Distance:	99.96
# 2021-03-03 15:15:38 - Accuracy Euclidean Distance:	99.97
#
# 2021-03-03 15:22:19 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 9000 steps:
# 2021-03-03 15:24:20 - Accuracy Cosine Distance:   	99.97
# 2021-03-03 15:24:20 - Accuracy Manhatten Distance:	99.97
# 2021-03-03 15:24:20 - Accuracy Euclidean Distance:	99.97
#
# 2021-03-03 15:24:20 - Save model to output/StackFAQ/models/triplet_hard_user_query_1.1
#
# 2021-03-03 15:27:33 - TripletEvaluator: Evaluating the model on val dataset after epoch 0:
# 2021-03-03 15:29:34 - Accuracy Cosine Distance:   	99.99
# 2021-03-03 15:29:34 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 15:29:34 - Accuracy Euclidean Distance:	99.99
#
# 2021-03-03 15:29:34 - Save model to output/StackFAQ/models/triplet_hard_user_query_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=9476.0, style=ProgressStyle(description_w…
# 2021-03-03 15:36:16 - TripletEvaluator: Evaluating the model on val dataset in epoch 1 after 1000 steps:
# 2021-03-03 15:38:18 - Accuracy Cosine Distance:   	99.99
# 2021-03-03 15:38:18 - Accuracy Manhatten Distance:	99.99
# 2021-03-03 15:38:18 - Accuracy Euclidean Distance:	99.99
#
# 2021-03-03 15:44:59 - TripletEvaluator: Evaluating the model on val dataset in epoch 1 after 2000 steps:
# 2021-03-03 15:47:00 - Accuracy Cosine Distance:   	99.98
# 2021-03-03 15:47:00 - Accuracy Manhatten Distance:	99.98
# 2021-03-03 15:47:00 - Accuracy Euclidean Distance:	99.98
#
# 2021-03-03 15:53:41 - TripletEvaluator: Evaluating the model on val dataset in epoch 1 after 3000 steps:
# 2021-03-03 15:55:43 - Accuracy Cosine Distance:   	99.99
# 2021-03-03 15:55:43 - Accuracy Manhatten Distance:	99.99
# 2021-03-03 15:55:43 - Accuracy Euclidean Distance:	99.99
#
# 2021-03-03 16:02:24 - TripletEvaluator: Evaluating the model on val dataset in epoch 1 after 4000 steps:
# 2021-03-03 16:04:26 - Accuracy Cosine Distance:   	99.99
# 2021-03-03 16:04:26 - Accuracy Manhatten Distance:	99.99
# 2021-03-03 16:04:26 - Accuracy Euclidean Distance:	99.99
#
# 2021-03-03 16:11:07 - TripletEvaluator: Evaluating the model on val dataset in epoch 1 after 5000 steps:
# 2021-03-03 16:13:08 - Accuracy Cosine Distance:   	99.99
# 2021-03-03 16:13:08 - Accuracy Manhatten Distance:	99.99
# 2021-03-03 16:13:08 - Accuracy Euclidean Distance:	99.99
#
# 2021-03-03 16:19:49 - TripletEvaluator: Evaluating the model on val dataset in epoch 1 after 6000 steps:
# 2021-03-03 16:21:51 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 16:21:51 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 16:21:51 - Accuracy Euclidean Distance:	100.00
#
# 2021-03-03 16:28:32 - TripletEvaluator: Evaluating the model on val dataset in epoch 1 after 7000 steps:
# 2021-03-03 16:30:33 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 16:30:33 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 16:30:33 - Accuracy Euclidean Distance:	100.00
#
# 2021-03-03 16:37:14 - TripletEvaluator: Evaluating the model on val dataset in epoch 1 after 8000 steps:
# 2021-03-03 16:39:15 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 16:39:15 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 16:39:15 - Accuracy Euclidean Distance:	100.00
#
# 2021-03-03 16:45:56 - TripletEvaluator: Evaluating the model on val dataset in epoch 1 after 9000 steps:
# 2021-03-03 16:47:58 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 16:47:58 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 16:47:58 - Accuracy Euclidean Distance:	100.00
#
#
# 2021-03-03 16:51:08 - TripletEvaluator: Evaluating the model on val dataset after epoch 1:
# 2021-03-03 16:53:10 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 16:53:10 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 16:53:10 - Accuracy Euclidean Distance:	100.00
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=9476.0, style=ProgressStyle(description_w…
# 2021-03-03 16:59:49 - TripletEvaluator: Evaluating the model on val dataset in epoch 2 after 1000 steps:
# 2021-03-03 17:01:51 - Accuracy Cosine Distance:   	99.99
# 2021-03-03 17:01:51 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 17:01:51 - Accuracy Euclidean Distance:	99.99
#
# 2021-03-03 17:08:31 - TripletEvaluator: Evaluating the model on val dataset in epoch 2 after 2000 steps:
# 2021-03-03 17:10:32 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 17:10:32 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 17:10:32 - Accuracy Euclidean Distance:	100.00
#
# 2021-03-03 17:17:14 - TripletEvaluator: Evaluating the model on val dataset in epoch 2 after 3000 steps:
# 2021-03-03 17:19:15 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 17:19:15 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 17:19:15 - Accuracy Euclidean Distance:	100.00
#
# 2021-03-03 17:25:56 - TripletEvaluator: Evaluating the model on val dataset in epoch 2 after 4000 steps:
# 2021-03-03 17:27:58 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 17:27:58 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 17:27:58 - Accuracy Euclidean Distance:	100.00
#
# 2021-03-03 17:34:39 - TripletEvaluator: Evaluating the model on val dataset in epoch 2 after 5000 steps:
# 2021-03-03 17:36:40 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 17:36:40 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 17:36:40 - Accuracy Euclidean Distance:	100.00
#
# 2021-03-03 17:43:21 - TripletEvaluator: Evaluating the model on val dataset in epoch 2 after 6000 steps:
# 2021-03-03 17:45:23 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 17:45:23 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 17:45:23 - Accuracy Euclidean Distance:	100.00
#
# 2021-03-03 17:52:02 - TripletEvaluator: Evaluating the model on val dataset in epoch 2 after 7000 steps:
# 2021-03-03 17:54:04 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 17:54:04 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 17:54:04 - Accuracy Euclidean Distance:	100.00
#
# 2021-03-03 18:00:45 - TripletEvaluator: Evaluating the model on val dataset in epoch 2 after 8000 steps:
# 2021-03-03 18:02:46 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 18:02:46 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 18:02:46 - Accuracy Euclidean Distance:	100.00
#
# 2021-03-03 18:09:26 - TripletEvaluator: Evaluating the model on val dataset in epoch 2 after 9000 steps:
# 2021-03-03 18:11:28 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 18:11:28 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 18:11:28 - Accuracy Euclidean Distance:	100.00
#
#
# 2021-03-03 18:14:39 - TripletEvaluator: Evaluating the model on val dataset after epoch 2:
# 2021-03-03 18:16:41 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 18:16:41 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 18:16:41 - Accuracy Euclidean Distance:	100.00
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=9476.0, style=ProgressStyle(description_w…
# 2021-03-03 18:23:22 - TripletEvaluator: Evaluating the model on val dataset in epoch 3 after 1000 steps:
# 2021-03-03 18:25:24 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 18:25:24 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 18:25:24 - Accuracy Euclidean Distance:	100.00
#
# 2021-03-03 18:32:05 - TripletEvaluator: Evaluating the model on val dataset in epoch 3 after 2000 steps:
# 2021-03-03 18:34:07 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 18:34:07 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 18:34:07 - Accuracy Euclidean Distance:	100.00
#
# 2021-03-03 18:40:48 - TripletEvaluator: Evaluating the model on val dataset in epoch 3 after 3000 steps:
# 2021-03-03 18:42:50 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 18:42:50 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 18:42:50 - Accuracy Euclidean Distance:	100.00
#
# 2021-03-03 18:49:30 - TripletEvaluator: Evaluating the model on val dataset in epoch 3 after 4000 steps:
# 2021-03-03 18:51:32 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 18:51:32 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 18:51:32 - Accuracy Euclidean Distance:	100.00
#
# 2021-03-03 18:58:12 - TripletEvaluator: Evaluating the model on val dataset in epoch 3 after 5000 steps:
# 2021-03-03 19:00:14 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 19:00:14 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 19:00:14 - Accuracy Euclidean Distance:	100.00
#
# 2021-03-03 19:06:55 - TripletEvaluator: Evaluating the model on val dataset in epoch 3 after 6000 steps:
# 2021-03-03 19:08:56 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 19:08:56 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 19:08:56 - Accuracy Euclidean Distance:	100.00
#
# 2021-03-03 19:15:37 - TripletEvaluator: Evaluating the model on val dataset in epoch 3 after 7000 steps:
# 2021-03-03 19:17:39 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 19:17:39 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 19:17:39 - Accuracy Euclidean Distance:	100.00
#
# 2021-03-03 19:24:20 - TripletEvaluator: Evaluating the model on val dataset in epoch 3 after 8000 steps:
# 2021-03-03 19:26:22 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 19:26:22 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 19:26:22 - Accuracy Euclidean Distance:	100.00
#
# 2021-03-03 19:33:05 - TripletEvaluator: Evaluating the model on val dataset in epoch 3 after 9000 steps:
# 2021-03-03 19:35:07 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 19:35:07 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 19:35:07 - Accuracy Euclidean Distance:	100.00
#
#
# 2021-03-03 19:38:19 - TripletEvaluator: Evaluating the model on val dataset after epoch 3:
# 2021-03-03 19:40:20 - Accuracy Cosine Distance:   	100.00
# 2021-03-03 19:40:20 - Accuracy Manhatten Distance:	100.00
# 2021-03-03 19:40:20 - Accuracy Euclidean Distance:	100.00
#
#
# 2021-03-03 19:40:20 - Evaluating model
# 2021-03-03 19:40:20 - Load pretrained SentenceTransformer: output/StackFAQ/models/triplet_hard_user_query_1.1
# 2021-03-03 19:40:20 - Load SentenceTransformer from folder: output/StackFAQ/models/triplet_hard_user_query_1.1
# 2021-03-03 19:40:22 - Use pytorch device: cuda
# 2021-03-03 19:40:22 - TripletEvaluator: Evaluating the model on test dataset:
# 2021-03-03 19:42:23 - Accuracy Cosine Distance:   	99.99
# 2021-03-03 19:42:23 - Accuracy Manhatten Distance:	99.99
# 2021-03-03 19:42:23 - Accuracy Euclidean Distance:	99.99

# %% [markdown]
# **query_type=user_query, neg_type="simple"**

# %%
# load simple_user_query_dataset.csv
simple_user_query_dataset = pd.read_csv('data/StackFAQ/dataset/triplet/user_query/simple_user_query_dataset.csv')
simple_user_query_dataset
# Out:
#                                                  question  ...                                           negative
# 0               How to make font strikethrough on github.  ...  There is a really nasty way, i do often. In be...
# 1               How to make font strikethrough on github.  ...  Also note that Twitter does not retain an infi...
# 2               How to make font strikethrough on github.  ...  This might not be what you're looking for, but...
# 3               How to make font strikethrough on github.  ...  There is another workaround that does not requ...
# 4               How to make font strikethrough on github.  ...  Flickchart keeps track of the movies you've se...
# ...                                                   ...  ...                                                ...
# 172411  I require the longer (em) dash in google docs,...  ...  Note: @Joe has created a JavaScript bookmarkle...
# 172412  I require the longer (em) dash in google docs,...  ...  In Account Settings, there's a "Linked Account...
# 172413  I require the longer (em) dash in google docs,...  ...  Open the Conversion in the Standard View of GM...
# 172414  I require the longer (em) dash in google docs,...  ...  Insert > Special Characters...   Make sure you...
# 172415  I require the longer (em) dash in google docs,...  ...  I like doodle.com . It is simple and integrate...
#
# [172416 rows x 3 columns]

# %%
simple_user_query_dataset.shape
# Out:
# (172416, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_simple_user_query = FAQ_BERT_Finetuning(
    loss_type="triplet", query_type='user_query', neg_type='simple', version="1.1", epochs=4, batch_size=16, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_simple_user_query.create_model(simple_user_query_dataset, output_path)
# Out:
# 2021-03-04 06:53:30 - Lock 140392638698512 acquired on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=442.0, style=ProgressStyle(description_…
# 2021-03-04 06:53:30 - Lock 140392638698512 released on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# 2021-03-04 06:53:30 - Lock 140392638764304 acquired on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=267967963.0, style=ProgressStyle(descri…
# 2021-03-04 06:53:34 - Lock 140392638764304 released on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# 2021-03-04 06:53:36 - Lock 140392638731024 acquired on /root/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# 2021-03-04 06:53:36 - Lock 140392638731024 released on /root/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# 2021-03-04 06:53:36 - Lock 140392625135376 acquired on /root/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466062.0, style=ProgressStyle(descripti…
# 2021-03-04 06:53:36 - Lock 140392625135376 released on /root/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# 2021-03-04 06:53:36 - Use pytorch device: cuda
# 2021-03-04 06:53:36 - Generating directory structure
# 2021-03-04 06:53:36 - Generating triplets for training
# 2021-03-04 06:53:49 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=4.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=8621.0, style=ProgressStyle(description_w…
# 2021-03-04 07:00:56 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 1000 steps:
# 2021-03-04 07:02:43 - Accuracy Cosine Distance:   	97.27
# 2021-03-04 07:02:43 - Accuracy Manhatten Distance:	97.34
# 2021-03-04 07:02:43 - Accuracy Euclidean Distance:	97.28
#
# 2021-03-04 07:02:43 - Save model to output/StackFAQ/models/triplet_simple_user_query_1.1
# 2021-03-04 07:09:39 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 2000 steps:
# 2021-03-04 07:11:27 - Accuracy Cosine Distance:   	98.57
# 2021-03-04 07:11:27 - Accuracy Manhatten Distance:	98.59
# 2021-03-04 07:11:27 - Accuracy Euclidean Distance:	98.58
#
# 2021-03-04 07:11:27 - Save model to output/StackFAQ/models/triplet_simple_user_query_1.1
# 2021-03-04 07:18:20 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 3000 steps:
# 2021-03-04 07:20:07 - Accuracy Cosine Distance:   	99.01
# 2021-03-04 07:20:07 - Accuracy Manhatten Distance:	99.00
# 2021-03-04 07:20:07 - Accuracy Euclidean Distance:	99.03
#
# 2021-03-04 07:20:07 - Save model to output/StackFAQ/models/triplet_simple_user_query_1.1
# 2021-03-04 07:26:59 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 4000 steps:
# 2021-03-04 07:28:45 - Accuracy Cosine Distance:   	99.15
# 2021-03-04 07:28:45 - Accuracy Manhatten Distance:	99.16
# 2021-03-04 07:28:45 - Accuracy Euclidean Distance:	99.16
#
# 2021-03-04 07:28:45 - Save model to output/StackFAQ/models/triplet_simple_user_query_1.1
# 2021-03-04 07:35:37 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 5000 steps:
# 2021-03-04 07:37:24 - Accuracy Cosine Distance:   	99.19
# 2021-03-04 07:37:24 - Accuracy Manhatten Distance:	99.21
# 2021-03-04 07:37:24 - Accuracy Euclidean Distance:	99.19
#
# 2021-03-04 07:37:24 - Save model to output/StackFAQ/models/triplet_simple_user_query_1.1
# 2021-03-04 07:44:15 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 6000 steps:
# 2021-03-04 07:46:01 - Accuracy Cosine Distance:   	99.30
# 2021-03-04 07:46:01 - Accuracy Manhatten Distance:	99.33
# 2021-03-04 07:46:01 - Accuracy Euclidean Distance:	99.31
#
# 2021-03-04 07:46:01 - Save model to output/StackFAQ/models/triplet_simple_user_query_1.1
# 2021-03-04 07:52:51 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 7000 steps:
# 2021-03-04 07:54:37 - Accuracy Cosine Distance:   	99.26
# 2021-03-04 07:54:37 - Accuracy Manhatten Distance:	99.26
# 2021-03-04 07:54:37 - Accuracy Euclidean Distance:	99.28
#
# 2021-03-04 08:01:26 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 8000 steps:
# 2021-03-04 08:03:12 - Accuracy Cosine Distance:   	99.26
# 2021-03-04 08:03:12 - Accuracy Manhatten Distance:	99.28
# 2021-03-04 08:03:12 - Accuracy Euclidean Distance:	99.26
#
#
# 2021-03-04 08:07:26 - TripletEvaluator: Evaluating the model on val dataset after epoch 0:
# 2021-03-04 08:09:13 - Accuracy Cosine Distance:   	99.37
# 2021-03-04 08:09:13 - Accuracy Manhatten Distance:	99.35
# 2021-03-04 08:09:13 - Accuracy Euclidean Distance:	99.37
#
# 2021-03-04 08:09:13 - Save model to output/StackFAQ/models/triplet_simple_user_query_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=8621.0, style=ProgressStyle(description_w…
# 2021-03-04 08:16:03 - TripletEvaluator: Evaluating the model on val dataset in epoch 1 after 1000 steps:
# 2021-03-04 08:17:49 - Accuracy Cosine Distance:   	99.36
# 2021-03-04 08:17:49 - Accuracy Manhatten Distance:	99.37
# 2021-03-04 08:17:49 - Accuracy Euclidean Distance:	99.37
#
# 2021-03-04 08:24:37 - TripletEvaluator: Evaluating the model on val dataset in epoch 1 after 2000 steps:
# 2021-03-04 08:26:24 - Accuracy Cosine Distance:   	99.36
# 2021-03-04 08:26:24 - Accuracy Manhatten Distance:	99.36
# 2021-03-04 08:26:24 - Accuracy Euclidean Distance:	99.36
#
# 2021-03-04 08:33:12 - TripletEvaluator: Evaluating the model on val dataset in epoch 1 after 3000 steps:
# 2021-03-04 08:34:59 - Accuracy Cosine Distance:   	99.40
# 2021-03-04 08:34:59 - Accuracy Manhatten Distance:	99.41
# 2021-03-04 08:34:59 - Accuracy Euclidean Distance:	99.40
#
# 2021-03-04 08:34:59 - Save model to output/StackFAQ/models/triplet_simple_user_query_1.1
# 2021-03-04 08:41:49 - TripletEvaluator: Evaluating the model on val dataset in epoch 1 after 4000 steps:
# 2021-03-04 08:43:35 - Accuracy Cosine Distance:   	99.43
# 2021-03-04 08:43:35 - Accuracy Manhatten Distance:	99.43
# 2021-03-04 08:43:35 - Accuracy Euclidean Distance:	99.43
#
# 2021-03-04 08:43:35 - Save model to output/StackFAQ/models/triplet_simple_user_query_1.1
# 2021-03-04 08:50:25 - TripletEvaluator: Evaluating the model on val dataset in epoch 1 after 5000 steps:
# 2021-03-04 08:52:11 - Accuracy Cosine Distance:   	99.41
# 2021-03-04 08:52:11 - Accuracy Manhatten Distance:	99.41
# 2021-03-04 08:52:11 - Accuracy Euclidean Distance:	99.41
#
# 2021-03-04 08:59:00 - TripletEvaluator: Evaluating the model on val dataset in epoch 1 after 6000 steps:
# 2021-03-04 09:00:47 - Accuracy Cosine Distance:   	99.36
# 2021-03-04 09:00:47 - Accuracy Manhatten Distance:	99.36
# 2021-03-04 09:00:47 - Accuracy Euclidean Distance:	99.36
#
# 2021-03-04 09:07:35 - TripletEvaluator: Evaluating the model on val dataset in epoch 1 after 7000 steps:
# 2021-03-04 09:09:22 - Accuracy Cosine Distance:   	99.42
# 2021-03-04 09:09:22 - Accuracy Manhatten Distance:	99.41
# 2021-03-04 09:09:22 - Accuracy Euclidean Distance:	99.42
#
# 2021-03-04 09:16:10 - TripletEvaluator: Evaluating the model on val dataset in epoch 1 after 8000 steps:
# 2021-03-04 09:17:57 - Accuracy Cosine Distance:   	99.35
# 2021-03-04 09:17:57 - Accuracy Manhatten Distance:	99.34
# 2021-03-04 09:17:57 - Accuracy Euclidean Distance:	99.36
#
#
# 2021-03-04 09:22:10 - TripletEvaluator: Evaluating the model on val dataset after epoch 1:
# 2021-03-04 09:23:57 - Accuracy Cosine Distance:   	99.38
# 2021-03-04 09:23:57 - Accuracy Manhatten Distance:	99.36
# 2021-03-04 09:23:57 - Accuracy Euclidean Distance:	99.37
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=8621.0, style=ProgressStyle(description_w…
# 2021-03-04 09:30:45 - TripletEvaluator: Evaluating the model on val dataset in epoch 2 after 1000 steps:
# 2021-03-04 09:32:32 - Accuracy Cosine Distance:   	99.38
# 2021-03-04 09:32:32 - Accuracy Manhatten Distance:	99.39
# 2021-03-04 09:32:32 - Accuracy Euclidean Distance:	99.38
#
# 2021-03-04 09:39:20 - TripletEvaluator: Evaluating the model on val dataset in epoch 2 after 2000 steps:
# 2021-03-04 09:41:07 - Accuracy Cosine Distance:   	99.36
# 2021-03-04 09:41:07 - Accuracy Manhatten Distance:	99.34
# 2021-03-04 09:41:07 - Accuracy Euclidean Distance:	99.36
#
# 2021-03-04 09:47:56 - TripletEvaluator: Evaluating the model on val dataset in epoch 2 after 3000 steps:
# 2021-03-04 09:49:42 - Accuracy Cosine Distance:   	99.39
# 2021-03-04 09:49:42 - Accuracy Manhatten Distance:	99.38
# 2021-03-04 09:49:42 - Accuracy Euclidean Distance:	99.39
#
# 2021-03-04 09:56:29 - TripletEvaluator: Evaluating the model on val dataset in epoch 2 after 4000 steps:
# 2021-03-04 09:58:16 - Accuracy Cosine Distance:   	99.33
# 2021-03-04 09:58:16 - Accuracy Manhatten Distance:	99.34
# 2021-03-04 09:58:16 - Accuracy Euclidean Distance:	99.34
#
# 2021-03-04 10:05:04 - TripletEvaluator: Evaluating the model on val dataset in epoch 2 after 5000 steps:
# 2021-03-04 10:06:51 - Accuracy Cosine Distance:   	99.36
# 2021-03-04 10:06:51 - Accuracy Manhatten Distance:	99.35
# 2021-03-04 10:06:51 - Accuracy Euclidean Distance:	99.36
#
# 2021-03-04 10:13:39 - TripletEvaluator: Evaluating the model on val dataset in epoch 2 after 6000 steps:
# 2021-03-04 10:15:26 - Accuracy Cosine Distance:   	99.40
# 2021-03-04 10:15:26 - Accuracy Manhatten Distance:	99.41
# 2021-03-04 10:15:26 - Accuracy Euclidean Distance:	99.41
#
# 2021-03-04 10:22:14 - TripletEvaluator: Evaluating the model on val dataset in epoch 2 after 7000 steps:
# 2021-03-04 10:24:01 - Accuracy Cosine Distance:   	99.39
# 2021-03-04 10:24:01 - Accuracy Manhatten Distance:	99.39
# 2021-03-04 10:24:01 - Accuracy Euclidean Distance:	99.40
#
# 2021-03-04 10:30:49 - TripletEvaluator: Evaluating the model on val dataset in epoch 2 after 8000 steps:
# 2021-03-04 10:32:35 - Accuracy Cosine Distance:   	99.41
# 2021-03-04 10:32:35 - Accuracy Manhatten Distance:	99.41
# 2021-03-04 10:32:35 - Accuracy Euclidean Distance:	99.41
#
#
# 2021-03-04 10:36:49 - TripletEvaluator: Evaluating the model on val dataset after epoch 2:
# 2021-03-04 10:38:35 - Accuracy Cosine Distance:   	99.40
# 2021-03-04 10:38:35 - Accuracy Manhatten Distance:	99.39
# 2021-03-04 10:38:35 - Accuracy Euclidean Distance:	99.39
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=8621.0, style=ProgressStyle(description_w…
# 2021-03-04 10:45:23 - TripletEvaluator: Evaluating the model on val dataset in epoch 3 after 1000 steps:
# 2021-03-04 10:47:09 - Accuracy Cosine Distance:   	99.34
# 2021-03-04 10:47:09 - Accuracy Manhatten Distance:	99.36
# 2021-03-04 10:47:09 - Accuracy Euclidean Distance:	99.34
#
# 2021-03-04 10:53:57 - TripletEvaluator: Evaluating the model on val dataset in epoch 3 after 2000 steps:
# 2021-03-04 10:55:44 - Accuracy Cosine Distance:   	99.34
# 2021-03-04 10:55:44 - Accuracy Manhatten Distance:	99.34
# 2021-03-04 10:55:44 - Accuracy Euclidean Distance:	99.36
#
# 2021-03-04 11:02:32 - TripletEvaluator: Evaluating the model on val dataset in epoch 3 after 3000 steps:
# 2021-03-04 11:04:18 - Accuracy Cosine Distance:   	99.34
# 2021-03-04 11:04:18 - Accuracy Manhatten Distance:	99.34
# 2021-03-04 11:04:18 - Accuracy Euclidean Distance:	99.34
#
# 2021-03-04 11:11:06 - TripletEvaluator: Evaluating the model on val dataset in epoch 3 after 4000 steps:
# 2021-03-04 11:12:52 - Accuracy Cosine Distance:   	99.31
# 2021-03-04 11:12:52 - Accuracy Manhatten Distance:	99.32
# 2021-03-04 11:12:52 - Accuracy Euclidean Distance:	99.31
#
# 2021-03-04 11:19:40 - TripletEvaluator: Evaluating the model on val dataset in epoch 3 after 5000 steps:
# 2021-03-04 11:21:27 - Accuracy Cosine Distance:   	99.33
# 2021-03-04 11:21:27 - Accuracy Manhatten Distance:	99.34
# 2021-03-04 11:21:27 - Accuracy Euclidean Distance:	99.33
#
# 2021-03-04 11:28:15 - TripletEvaluator: Evaluating the model on val dataset in epoch 3 after 6000 steps:
# 2021-03-04 11:30:02 - Accuracy Cosine Distance:   	99.32
# 2021-03-04 11:30:02 - Accuracy Manhatten Distance:	99.32
# 2021-03-04 11:30:02 - Accuracy Euclidean Distance:	99.32
#
# 2021-03-04 11:36:50 - TripletEvaluator: Evaluating the model on val dataset in epoch 3 after 7000 steps:
# 2021-03-04 11:38:36 - Accuracy Cosine Distance:   	99.34
# 2021-03-04 11:38:36 - Accuracy Manhatten Distance:	99.33
# 2021-03-04 11:38:36 - Accuracy Euclidean Distance:	99.34
#
# 2021-03-04 11:45:25 - TripletEvaluator: Evaluating the model on val dataset in epoch 3 after 8000 steps:
# 2021-03-04 11:47:11 - Accuracy Cosine Distance:   	99.33
# 2021-03-04 11:47:11 - Accuracy Manhatten Distance:	99.33
# 2021-03-04 11:47:11 - Accuracy Euclidean Distance:	99.33
#
#
# 2021-03-04 11:51:24 - TripletEvaluator: Evaluating the model on val dataset after epoch 3:
# 2021-03-04 11:53:11 - Accuracy Cosine Distance:   	99.34
# 2021-03-04 11:53:11 - Accuracy Manhatten Distance:	99.33
# 2021-03-04 11:53:11 - Accuracy Euclidean Distance:	99.33
#
#
# 2021-03-04 11:53:11 - Evaluating model
# 2021-03-04 11:53:11 - Load pretrained SentenceTransformer: output/StackFAQ/models/triplet_simple_user_query_1.1
# 2021-03-04 11:53:11 - Load SentenceTransformer from folder: output/StackFAQ/models/triplet_simple_user_query_1.1
# 2021-03-04 11:53:13 - Use pytorch device: cuda
# 2021-03-04 11:53:13 - TripletEvaluator: Evaluating the model on test dataset:
# 2021-03-04 11:54:59 - Accuracy Cosine Distance:   	99.22
# 2021-03-04 11:54:59 - Accuracy Manhatten Distance:	99.22
# 2021-03-04 11:54:59 - Accuracy Euclidean Distance:	99.23

# %% [markdown]
# **BERT-Finetuning with Softmax Loss**

# %% [markdown]
# **query_type=faq, neg_type="hard"**

# %%
# load hard_faq_dataset.csv
hard_faq_dataset = pd.read_csv('data/StackFAQ/dataset/softmax/faq/hard_faq_dataset.csv')
hard_faq_dataset
# Out:
#                                                 question  ... label
# 0              How to make font strikethrough on github.  ...     1
# 1      Is it possible to get  strikethrough letter fo...  ...     1
# 2                 Making the text on github crossed out.  ...     1
# 3      Introducing stikethrough formatting on markdow...  ...     1
# 4      The <s> tag for font on github markdown doesnt...  ...     1
# ...                                                  ...  ...   ...
# 10898  How to create an em dash in Google Drive (Goog...  ...     0
# 10899  How to create an em dash in Google Drive (Goog...  ...     0
# 10900  How to create an em dash in Google Drive (Goog...  ...     0
# 10901  How to create an em dash in Google Drive (Goog...  ...     0
# 10902  How to create an em dash in Google Drive (Goog...  ...     0
#
# [10903 rows x 3 columns]

# %%
# check dataset shape
hard_faq_dataset.shape
# Out:
# (10903, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_hard_faq = FAQ_BERT_Finetuning(
    loss_type="softmax", query_type='faq', neg_type='hard', version="1.1", epochs=4, batch_size=16, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_hard_faq.create_model(hard_faq_dataset, output_path)
# Out:
# 2021-03-07 16:15:28 - Lock 140234137111376 acquired on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=442.0, style=ProgressStyle(description_…
# 2021-03-07 16:15:28 - Lock 140234137111376 released on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# 2021-03-07 16:15:28 - Lock 140234168340048 acquired on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=267967963.0, style=ProgressStyle(descri…
# 2021-03-07 16:15:33 - Lock 140234168340048 released on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2021-03-07 16:15:35 - Lock 140234113114000 acquired on /root/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# 2021-03-07 16:15:35 - Lock 140234113114000 released on /root/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# 2021-03-07 16:15:35 - Lock 140232402799248 acquired on /root/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466062.0, style=ProgressStyle(descripti…
# 2021-03-07 16:15:35 - Lock 140232402799248 released on /root/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# 2021-03-07 16:15:35 - Use pytorch device: cuda
# 2021-03-07 16:15:35 - Generating directory structure
# 2021-03-07 16:15:35 - Generating triplets for training
# 2021-03-07 16:15:36 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=4.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=546.0, style=ProgressStyle(description_wi…
# 2021-03-07 16:20:26 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 0:
# 2021-03-07 16:20:42 - Accuracy:           92.30	(Threshold: 0.3067)
# 2021-03-07 16:20:42 - F1:                 94.51	(Threshold: 0.3067)
# 2021-03-07 16:20:42 - Precision:          96.53
# 2021-03-07 16:20:42 - Recall:             92.57
# 2021-03-07 16:20:42 - Average Precision:  98.83
#
# 2021-03-07 16:20:42 - Save model to output/StackFAQ/models/softmax_hard_faq_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=546.0, style=ProgressStyle(description_wi…
# 2021-03-07 16:25:26 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 1:
# 2021-03-07 16:25:42 - Accuracy:           94.59	(Threshold: 0.7987)
# 2021-03-07 16:25:42 - F1:                 96.09	(Threshold: 0.7987)
# 2021-03-07 16:25:42 - Precision:          99.59
# 2021-03-07 16:25:42 - Recall:             92.83
# 2021-03-07 16:25:42 - Average Precision:  99.21
#
# 2021-03-07 16:25:42 - Save model to output/StackFAQ/models/softmax_hard_faq_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=546.0, style=ProgressStyle(description_wi…
# 2021-03-07 16:30:29 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 2:
# 2021-03-07 16:30:45 - Accuracy:           95.05	(Threshold: 0.4851)
# 2021-03-07 16:30:45 - F1:                 96.46	(Threshold: 0.4851)
# 2021-03-07 16:30:45 - Precision:          98.79
# 2021-03-07 16:30:45 - Recall:             94.24
# 2021-03-07 16:30:45 - Average Precision:  99.36
#
# 2021-03-07 16:30:45 - Save model to output/StackFAQ/models/softmax_hard_faq_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=546.0, style=ProgressStyle(description_wi…
# 2021-03-07 16:35:33 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 3:
# 2021-03-07 16:35:49 - Accuracy:           95.05	(Threshold: 0.7204)
# 2021-03-07 16:35:49 - F1:                 96.49	(Threshold: 0.7204)
# 2021-03-07 16:35:49 - Precision:          98.02
# 2021-03-07 16:35:49 - Recall:             95.01
# 2021-03-07 16:35:49 - Average Precision:  99.36
#
#
# 2021-03-07 16:35:49 - Evaluating model
# 2021-03-07 16:35:51 - Use pytorch device: cuda
# 2021-03-07 16:35:51 - CEBinaryClassificationEvaluator: Evaluating the model on test dataset:
# 2021-03-07 16:36:08 - Accuracy:           93.67	(Threshold: 0.8105)
# 2021-03-07 16:36:08 - F1:                 95.54	(Threshold: 0.1605)
# 2021-03-07 16:36:08 - Precision:          95.91
# 2021-03-07 16:36:08 - Recall:             95.18
# 2021-03-07 16:36:08 - Average Precision:  99.21

# %% [markdown]
# **query_type=faq, neg_type="simple"**

# %%
# load simple_faq_dataset.csv
simple_faq_dataset = pd.read_csv('data/StackFAQ/dataset/softmax/faq/simple_faq_dataset.csv')
simple_faq_dataset
# Out:
#        label  ...                                             answer
# 0          1  ...                   Use ~~tildes around the words~~.
# 1          1  ...  I just used the following syntax  <del> ... </...
# 2          1  ...  from here :   Go here: http://www.facebook.com...
# 3          1  ...  Go to "Your Account".  Go to "Deactivate Accou...
# 4          1  ...  It is not neccessary to go through the deactiv...
# ...      ...  ...                                                ...
# 17970      0  ...  If you are talking about searching, then @akir...
# 17971      0  ...  I am actually almost certain it has to do with...
# 17972      0  ...  gdocs2md does a good job of converting Google ...
# 17973      0  ...  I have created an html5 application for this. ...
# 17974      0  ...  We've built Paperpile to solve this problem: h...
#
# [17975 rows x 3 columns]

# %%
simple_faq_dataset.shape
# Out:
# (17975, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_simple_faq = FAQ_BERT_Finetuning(
    loss_type="softmax", query_type='faq', neg_type='simple', version="1.1", epochs=4, batch_size=16, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_simple_faq.create_model(simple_faq_dataset, output_path)
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2021-03-07 16:43:56 - Use pytorch device: cuda
# 2021-03-07 16:43:56 - Generating directory structure
# 2021-03-07 16:43:56 - Generating triplets for training
# 2021-03-07 16:43:58 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=4.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=899.0, style=ProgressStyle(description_wi…
# 2021-03-07 16:51:54 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 0:
# 2021-03-07 16:52:20 - Accuracy:           95.94	(Threshold: 0.2926)
# 2021-03-07 16:52:20 - F1:                 38.67	(Threshold: 0.0677)
# 2021-03-07 16:52:20 - Precision:          38.16
# 2021-03-07 16:52:20 - Recall:             39.19
# 2021-03-07 16:52:20 - Average Precision:  28.85
#
# 2021-03-07 16:52:20 - Save model to output/StackFAQ/models/softmax_simple_faq_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=899.0, style=ProgressStyle(description_wi…
# 2021-03-07 17:00:16 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 1:
# 2021-03-07 17:00:42 - Accuracy:           96.66	(Threshold: 0.5006)
# 2021-03-07 17:00:42 - F1:                 53.66	(Threshold: 0.0447)
# 2021-03-07 17:00:42 - Precision:          48.89
# 2021-03-07 17:00:42 - Recall:             59.46
# 2021-03-07 17:00:42 - Average Precision:  49.24
#
# 2021-03-07 17:00:42 - Save model to output/StackFAQ/models/softmax_simple_faq_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=899.0, style=ProgressStyle(description_wi…
# 2021-03-07 17:08:42 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 2:
# 2021-03-07 17:09:07 - Accuracy:           96.72	(Threshold: 0.8452)
# 2021-03-07 17:09:07 - F1:                 55.76	(Threshold: 0.0372)
# 2021-03-07 17:09:07 - Precision:          50.55
# 2021-03-07 17:09:07 - Recall:             62.16
# 2021-03-07 17:09:07 - Average Precision:  50.88
#
# 2021-03-07 17:09:07 - Save model to output/StackFAQ/models/softmax_simple_faq_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=899.0, style=ProgressStyle(description_wi…
# 2021-03-07 17:17:10 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 3:
# 2021-03-07 17:17:36 - Accuracy:           96.66	(Threshold: 0.8394)
# 2021-03-07 17:17:36 - F1:                 56.79	(Threshold: 0.0980)
# 2021-03-07 17:17:36 - Precision:          52.27
# 2021-03-07 17:17:36 - Recall:             62.16
# 2021-03-07 17:17:36 - Average Precision:  53.15
#
# 2021-03-07 17:17:36 - Save model to output/StackFAQ/models/softmax_simple_faq_1.1
#
# 2021-03-07 17:17:37 - Evaluating model
# 2021-03-07 17:17:39 - Use pytorch device: cuda
# 2021-03-07 17:17:39 - CEBinaryClassificationEvaluator: Evaluating the model on test dataset:
# 2021-03-07 17:18:04 - Accuracy:           96.61	(Threshold: 0.8025)
# 2021-03-07 17:18:04 - F1:                 60.36	(Threshold: 0.0995)
# 2021-03-07 17:18:04 - Precision:          58.62
# 2021-03-07 17:18:04 - Recall:             62.20
# 2021-03-07 17:18:04 - Average Precision:  56.25

# %% [markdown]
# **query_type=user_query, neg_type="hard"**

# %%
# load hard_user_query_dataset.csv
hard_user_query_dataset = pd.read_csv('data/StackFAQ/dataset/softmax/user_query/hard_user_query_dataset.csv')
hard_user_query_dataset
# Out:
#                                                 question  ... label
# 0              How to make font strikethrough on github.  ...     1
# 1      Is it possible to get  strikethrough letter fo...  ...     1
# 2                 Making the text on github crossed out.  ...     1
# 3      Introducing stikethrough formatting on markdow...  ...     1
# 4      The <s> tag for font on github markdown doesnt...  ...     1
# ...                                                  ...  ...   ...
# 40839  How to create an em dash in Google Drive (Goog...  ...     0
# 40840  How to create an em dash in Google Drive (Goog...  ...     0
# 40841  How to create an em dash in Google Drive (Goog...  ...     0
# 40842  How to create an em dash in Google Drive (Goog...  ...     0
# 40843  How to create an em dash in Google Drive (Goog...  ...     0
#
# [40844 rows x 3 columns]

# %%
hard_user_query_dataset.shape
# Out:
# (40844, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_hard_user_query = FAQ_BERT_Finetuning(
    loss_type="softmax", query_type='user_query', neg_type='hard', version="1.1", epochs=4, batch_size=16, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_hard_user_query.create_model(hard_user_query_dataset, output_path)
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2021-03-07 17:21:15 - Use pytorch device: cuda
# 2021-03-07 17:21:15 - Generating directory structure
# 2021-03-07 17:21:15 - Generating triplets for training
# 2021-03-07 17:21:18 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=4.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=2043.0, style=ProgressStyle(description_w…
# 2021-03-07 17:30:47 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset in epoch 0 after 1000 steps:
# 2021-03-07 17:31:46 - Accuracy:           81.88	(Threshold: 0.4778)
# 2021-03-07 17:31:46 - F1:                 35.42	(Threshold: 0.2191)
# 2021-03-07 17:31:46 - Precision:          25.25
# 2021-03-07 17:31:46 - Recall:             59.31
# 2021-03-07 17:31:46 - Average Precision:  30.97
#
# 2021-03-07 17:31:46 - Save model to output/StackFAQ/models/softmax_hard_user_query_1.1
# 2021-03-07 17:41:24 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset in epoch 0 after 2000 steps:
# 2021-03-07 17:42:24 - Accuracy:           82.59	(Threshold: 0.4608)
# 2021-03-07 17:42:24 - F1:                 42.37	(Threshold: 0.2848)
# 2021-03-07 17:42:24 - Precision:          37.88
# 2021-03-07 17:42:24 - Recall:             48.08
# 2021-03-07 17:42:24 - Average Precision:  40.09
#
# 2021-03-07 17:42:24 - Save model to output/StackFAQ/models/softmax_hard_user_query_1.1
#
# 2021-03-07 17:42:50 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 0:
# 2021-03-07 17:43:50 - Accuracy:           82.67	(Threshold: 0.5532)
# 2021-03-07 17:43:50 - F1:                 44.15	(Threshold: 0.2091)
# 2021-03-07 17:43:50 - Precision:          36.61
# 2021-03-07 17:43:50 - Recall:             55.61
# 2021-03-07 17:43:50 - Average Precision:  42.08
#
# 2021-03-07 17:43:50 - Save model to output/StackFAQ/models/softmax_hard_user_query_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=2043.0, style=ProgressStyle(description_w…
# 2021-03-07 17:53:24 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset in epoch 1 after 1000 steps:
# 2021-03-07 17:54:24 - Accuracy:           86.46	(Threshold: 0.5304)
# 2021-03-07 17:54:24 - F1:                 59.52	(Threshold: 0.2572)
# 2021-03-07 17:54:24 - Precision:          52.14
# 2021-03-07 17:54:24 - Recall:             69.35
# 2021-03-07 17:54:24 - Average Precision:  65.36
#
# 2021-03-07 17:54:24 - Save model to output/StackFAQ/models/softmax_hard_user_query_1.1
# 2021-03-07 18:04:05 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset in epoch 1 after 2000 steps:
# 2021-03-07 18:05:04 - Accuracy:           88.96	(Threshold: 0.5783)
# 2021-03-07 18:05:04 - F1:                 67.64	(Threshold: 0.4167)
# 2021-03-07 18:05:04 - Precision:          71.47
# 2021-03-07 18:05:04 - Recall:             64.20
# 2021-03-07 18:05:04 - Average Precision:  76.19
#
# 2021-03-07 18:05:04 - Save model to output/StackFAQ/models/softmax_hard_user_query_1.1
#
# 2021-03-07 18:05:28 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch
# 2021-03-07 18:52:41 - Average Precision:  85.12

# %% [markdown]
# **query_type=user_query, neg_type="simple"**

# %%
# load simple_user_query_dataset.csv
simple_user_query_dataset = pd.read_csv('data/StackFAQ/dataset/softmax/user_query/simple_user_query_dataset.csv')
simple_user_query_dataset
# Out:
#         label  ...                                             answer
# 0           1  ...                   Use ~~tildes around the words~~.
# 1           1  ...                   Use ~~tildes around the words~~.
# 2           1  ...                   Use ~~tildes around the words~~.
# 3           1  ...                   Use ~~tildes around the words~~.
# 4           1  ...                   Use ~~tildes around the words~~.
# ...       ...  ...                                                ...
# 179595      0  ...  Note: @Joe has created a JavaScript bookmarkle...
# 179596      0  ...  In Account Settings, there's a "Linked Account...
# 179597      0  ...  Open the Conversion in the Standard View of GM...
# 179598      0  ...  Insert > Special Characters...   Make sure you...
# 179599      0  ...  I like doodle.com . It is simple and integrate...
#
# [179600 rows x 3 columns]

# %%
simple_user_query_dataset.shape
# Out:
# (179600, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_simple_user_query = FAQ_BERT_Finetuning(
    loss_type="softmax", query_type='user_query', neg_type='simple', version="1.1", epochs=4, batch_size=16, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_simple_user_query.create_model(simple_user_query_dataset, output_path)
# Out:
# 2021-03-08 11:57:41 - Lock 140423188811856 acquired on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=442.0, style=ProgressStyle(description_…
# 2021-03-08 11:57:42 - Lock 140423188811856 released on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# 2021-03-08 11:57:42 - Lock 140423177645648 acquired on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=267967963.0, style=ProgressStyle(descri…
# 2021-03-08 11:57:49 - Lock 140423177645648 released on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2021-03-08 11:57:52 - Lock 140423177642896 acquired on /root/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# 2021-03-08 11:57:53 - Lock 140423177642896 released on /root/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# 2021-03-08 11:57:53 - Lock 140423031053392 acquired on /root/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466062.0, style=ProgressStyle(descripti…
# 2021-03-08 11:57:54 - Lock 140423031053392 released on /root/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# 2021-03-08 11:57:54 - Use pytorch device: cuda
# 2021-03-08 11:57:54 - Generating directory structure
# 2021-03-08 11:57:54 - Generating triplets for training
# 2021-03-08 11:58:15 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=4.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=8980.0, style=ProgressStyle(description_w…
# 2021-03-08 12:03:48 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset in epoch 0 after 1000 steps:
# 2021-03-08 12:05:57 - Accuracy:           95.92	(Threshold: 0.0837)
# 2021-03-08 12:05:57 - F1:                 19.80	(Threshold: 0.0352)
# 2021-03-08 12:05:57 - Precision:          16.17
# 2021-03-08 12:05:57 - Recall:             25.54
# 2021-03-08 12:05:57 - Average Precision:  12.47
#
# 2021-03-08 12:05:57 - Save model to output/StackFAQ/models/softmax_simple_user_query_1.1
# 2021-03-08 12:11:26 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset in epoch 0 after 2000 steps:
# 2021-03-08 12:13:35 - Accuracy:           96.29	(Threshold: 0.6456)
# 2021-03-08 12:13:35 - F1:                 46.51	(Threshold: 0.1432)
# 2021-03-08 12:13:35 - Precision:          44.33
# 2021-03-08 12:13:35 - Recall:             48.91
# 2021-03-08 12:13:35 - Average Precision:  43.06
#
# 2021-03-08 12:13:35 - Save model to output/StackFAQ/models/softmax_simple_user_query_1.1
# 2021-03-08 12:19:03 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset in epoch 0 after 3000 steps:
# 2021-03-08 12:21:12 - Accuracy:           96.58	(Threshold: 0.3806)
# 2021-03-08 12:21:12 - F1:                 51.90	(Threshold: 0.0904)
# 2021-03-08 12:21:12 - Precision:          48.69
# 2021-03-08 12:21:12 - Recall:             55.57
# 2021-03-08 12:21:12 - Average Precision:  50.93
#
# 2021-03-08 12:21:12 - Save model to output/StackFAQ/models/softmax_simple_user_query_1.1
# 2021-03-08 12:26:36 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset in epoch 0 after 4000 steps:
# 2021-03-08 12:28:44 - Accuracy:           96.71	(Threshold: 0.3426)
# 2021-03-08 12:28:44 - F1:                 55.69	(Threshold: 0.1056)
# 2021-03-08 12:28:44 - Precision:          52.87
# 2021-03-08 12:28:44 - Recall:             58.83
# 2021-03-08 12:28:44 - Average Precision:  55.48
#
# 2021-03-08 12:28:44 - Save model to output/StackFAQ/models/softmax_simple_user_query_1.1
# 2021-03-08