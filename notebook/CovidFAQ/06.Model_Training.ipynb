# %% [markdown]
# **BERT-Finetuning with Triplet Loss**

# %%
# install required dependencies
# !pip3 install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading https://files.pythonhosted.org/packages/6a/e2/84d6acfcee2d83164149778a33b6bdd1a74e1bcb59b2b2cd1b861359b339/sentence-transformers-0.4.1.2.tar.gz (64kB)
#      |████████████████████████████████| 71kB 5.7MB/s
# Collecting transformers<5.0.0,>=3.1.0
#   Downloading https://files.pythonhosted.org/packages/f9/54/5ca07ec9569d2f232f3166de5457b63943882f7950ddfcc887732fc7fb23/transformers-4.3.3-py3-none-any.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 12.9MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.41.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.8.0+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.19.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.22.2.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.2.5)
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/f5/99/e0808cb947ba10f575839c43e8fafc9cc44e4a7a2c8f79c60db48220a577/sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 50.4MB/s
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers) (3.7.0)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/71/23/2ddc317b2121117bf34dd00f5b0de194158f2a44ee2bf5e47c7166878a97/tokenizers-0.10.1-cp37-cp37m-manylinux2010_x86_64.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 51.8MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers) (2019.12.20)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers) (20.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers) (3.0.12)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 52.3MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers) (2.23.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence-transformers) (3.7.4.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers<5.0.0,>=3.1.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers<5.0.0,>=3.1.0->sentence-transformers) (2.4.7)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=3.1.0->sentence-transformers) (7.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers) (3.0.4)
# Building wheels for collected packages: sentence-transformers, sacremoses
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-0.4.1.2-cp37-none-any.whl size=103068 sha256=3b0712e69ef4ac69981be5125eb5ed42ca7b96ef8ac7c1e61ba90dd66e4ff9f6
#   Stored in directory: /root/.cache/pip/wheels/3d/33/d1/5703dd56199c09d4a1b41e0c07fb4e7765a84d787cbdc48ac3
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp37-none-any.whl size=893262 sha256=2f00f166ca1ca186f4fc8842bd63282041616cc03cb40c697f19e56802a73e67
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sentence-transformers sacremoses
# Installing collected packages: tokenizers, sacremoses, transformers, sentencepiece, sentence-transformers
# Successfully installed sacremoses-0.0.43 sentence-transformers-0.4.1.2 sentencepiece-0.1.95 tokenizers-0.10.1 transformers-4.3.3

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/BERT-FAQ
# Out:
# /content/drive/MyDrive/BERT-FAQ

# %%
# import required libraries
import pandas as pd
from faq_bert_finetuning import FAQ_BERT_Finetuning
from shared.utils import make_dirs

# %%
# define output path to save model & evaluation files
output_path = 'output/CovidFAQ'
make_dirs(output_path)

# %% [markdown]
# **query_type=faq, neg_type="hard"**

# %%
# load hard_faq_dataset.csv
hard_faq_dataset = pd.read_csv('data/CovidFAQ/dataset/triplet/faq/hard_faq_dataset.csv')
hard_faq_dataset
# Out:
#                                                question  ...                                           negative
# 0                                    What is COVID-19?   ...  All 50 states in the U.S., as well as D.C., Pu...
# 1                                    What is COVID-19?   ...  SARS-CoV-2 refers to the virus that causes COV...
# 2                                    What is COVID-19?   ...  Most people with mild coronavirus illness will...
# 3                                    What is COVID-19?   ...  Social distancing is one of the most effective...
# 4                                    What is COVID-19?   ...  MERs is Middle East Respiratory Syndrome. It i...
# ...                                                 ...  ...                                                ...
# 1699  I have packages coming from China... am I at r...  ...  COVID-19 is being spread through respiratory d...
# 1700  I have packages coming from China... am I at r...  ...  It is able to spread person-to-person. The spr...
# 1701  I have packages coming from China... am I at r...  ...  The best way to prevent illness from COVID-19 ...
# 1702  I have packages coming from China... am I at r...  ...  Masks are only helpful in preventing people wh...
# 1703  I have packages coming from China... am I at r...  ...  You should quarantine yourself for at least 14...
#
# [1704 rows x 3 columns]

# %%
# check dataset shape
hard_faq_dataset.shape
# Out:
# (1704, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_hard_faq = FAQ_BERT_Finetuning(
    loss_type="triplet", query_type='faq', neg_type='hard', version="1.1", epochs=4, batch_size=16, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_hard_faq.create_model(hard_faq_dataset, output_path)
# Out:
# 2021-03-11 13:52:26 - Lock 140655569851024 acquired on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=442.0, style=ProgressStyle(description_…
# 2021-03-11 13:52:26 - Lock 140655569851024 released on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# 2021-03-11 13:52:26 - Lock 140657358237456 acquired on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=267967963.0, style=ProgressStyle(descri…
# 2021-03-11 13:52:31 - Lock 140657358237456 released on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# 2021-03-11 13:52:33 - Lock 140655569746384 acquired on /root/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# 2021-03-11 13:52:33 - Lock 140655569746384 released on /root/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# 2021-03-11 13:52:33 - Lock 140655705691216 acquired on /root/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466062.0, style=ProgressStyle(descripti…
# 2021-03-11 13:52:34 - Lock 140655705691216 released on /root/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# 2021-03-11 13:52:34 - Use pytorch device: cuda
# 2021-03-11 13:52:34 - Generating directory structure
# 2021-03-11 13:52:34 - Generating triplets for training
# 2021-03-11 13:52:34 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=4.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=86.0, style=ProgressStyle(description_wid…
# 2021-03-11 13:53:06 - TripletEvaluator: Evaluating the model on val dataset after epoch 0:
# 2021-03-11 13:53:06 - Accuracy Cosine Distance:   	97.08
# 2021-03-11 13:53:06 - Accuracy Manhatten Distance:	96.49
# 2021-03-11 13:53:06 - Accuracy Euclidean Distance:	96.49
#
# 2021-03-11 13:53:06 - Save model to output/CovidFAQ/models/triplet_hard_faq_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=86.0, style=ProgressStyle(description_wid…
# 2021-03-11 13:53:29 - TripletEvaluator: Evaluating the model on val dataset after epoch 1:
# 2021-03-11 13:53:30 - Accuracy Cosine Distance:   	98.25
# 2021-03-11 13:53:30 - Accuracy Manhatten Distance:	98.25
# 2021-03-11 13:53:30 - Accuracy Euclidean Distance:	98.25
#
# 2021-03-11 13:53:30 - Save model to output/CovidFAQ/models/triplet_hard_faq_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=86.0, style=ProgressStyle(description_wid…
# 2021-03-11 13:53:52 - TripletEvaluator: Evaluating the model on val dataset after epoch 2:
# 2021-03-11 13:53:53 - Accuracy Cosine Distance:   	98.83
# 2021-03-11 13:53:53 - Accuracy Manhatten Distance:	98.83
# 2021-03-11 13:53:53 - Accuracy Euclidean Distance:	98.83
#
# 2021-03-11 13:53:53 - Save model to output/CovidFAQ/models/triplet_hard_faq_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=86.0, style=ProgressStyle(description_wid…
# 2021-03-11 13:54:15 - TripletEvaluator: Evaluating the model on val dataset after epoch 3:
# 2021-03-11 13:54:16 - Accuracy Cosine Distance:   	98.83
# 2021-03-11 13:54:16 - Accuracy Manhatten Distance:	98.83
# 2021-03-11 13:54:16 - Accuracy Euclidean Distance:	98.83
#
#
# 2021-03-11 13:54:16 - Evaluating model
# 2021-03-11 13:54:16 - Load pretrained SentenceTransformer: output/CovidFAQ/models/triplet_hard_faq_1.1
# 2021-03-11 13:54:16 - Load SentenceTransformer from folder: output/CovidFAQ/models/triplet_hard_faq_1.1
# 2021-03-11 13:54:17 - Use pytorch device: cuda
# 2021-03-11 13:54:17 - TripletEvaluator: Evaluating the model on test dataset:
# 2021-03-11 13:54:18 - Accuracy Cosine Distance:   	99.41
# 2021-03-11 13:54:18 - Accuracy Manhatten Distance:	99.41
# 2021-03-11 13:54:18 - Accuracy Euclidean Distance:	99.41

# %% [markdown]
# **query_type=faq, neg_type="simple"**

# %%
# load simple_faq_dataset.csv
simple_faq_dataset = pd.read_csv('data/CovidFAQ/dataset/triplet/faq/simple_faq_dataset.csv')
simple_faq_dataset
# Out:
#                                                question  ...                                           negative
# 0                                    What is COVID-19?   ...  MERs is Middle East Respiratory Syndrome. It i...
# 1                                    What is COVID-19?   ...  You should quarantine yourself for at least 14...
# 2                                    What is COVID-19?   ...  Social distancing is one of the most effective...
# 3                                    What is COVID-19?   ...  A novel, or new, coronavirus is one that has n...
# 4                                    What is COVID-19?   ...  No. They have the same symptoms, though it may...
# ...                                                 ...  ...                                                ...
# 1627  I have packages coming from China... am I at r...  ...  Experts believe that this is posisble, though ...
# 1628  I have packages coming from China... am I at r...  ...  Reported illnesses have ranged from mild sympt...
# 1629  I have packages coming from China... am I at r...  ...  If you have developed symptoms like fever, cou...
# 1630  I have packages coming from China... am I at r...  ...  Face masks, including fabric ones, are only re...
# 1631  I have packages coming from China... am I at r...  ...  Right now, our current understanding of how CO...
#
# [1632 rows x 3 columns]

# %%
simple_faq_dataset.shape
# Out:
# (1632, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_simple_faq = FAQ_BERT_Finetuning(
    loss_type="triplet", query_type='faq', neg_type='simple', version="1.1", epochs=4, batch_size=16, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_simple_faq.create_model(simple_faq_dataset, output_path)
# Out:
# 2021-03-11 13:55:19 - Use pytorch device: cuda
# 2021-03-11 13:55:19 - Generating directory structure
# 2021-03-11 13:55:19 - Generating triplets for training
# 2021-03-11 13:55:19 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=4.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=82.0, style=ProgressStyle(description_wid…
# 2021-03-11 13:55:39 - TripletEvaluator: Evaluating the model on val dataset after epoch 0:
# 2021-03-11 13:55:40 - Accuracy Cosine Distance:   	98.78
# 2021-03-11 13:55:40 - Accuracy Manhatten Distance:	98.78
# 2021-03-11 13:55:40 - Accuracy Euclidean Distance:	98.78
#
# 2021-03-11 13:55:40 - Save model to output/CovidFAQ/models/triplet_simple_faq_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=82.0, style=ProgressStyle(description_wid…
# 2021-03-11 13:56:01 - TripletEvaluator: Evaluating the model on val dataset after epoch 1:
# 2021-03-11 13:56:01 - Accuracy Cosine Distance:   	100.00
# 2021-03-11 13:56:01 - Accuracy Manhatten Distance:	100.00
# 2021-03-11 13:56:01 - Accuracy Euclidean Distance:	100.00
#
# 2021-03-11 13:56:01 - Save model to output/CovidFAQ/models/triplet_simple_faq_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=82.0, style=ProgressStyle(description_wid…
# 2021-03-11 13:56:23 - TripletEvaluator: Evaluating the model on val dataset after epoch 2:
# 2021-03-11 13:56:23 - Accuracy Cosine Distance:   	100.00
# 2021-03-11 13:56:23 - Accuracy Manhatten Distance:	100.00
# 2021-03-11 13:56:23 - Accuracy Euclidean Distance:	100.00
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=82.0, style=ProgressStyle(description_wid…
# 2021-03-11 13:56:43 - TripletEvaluator: Evaluating the model on val dataset after epoch 3:
# 2021-03-11 13:56:44 - Accuracy Cosine Distance:   	100.00
# 2021-03-11 13:56:44 - Accuracy Manhatten Distance:	100.00
# 2021-03-11 13:56:44 - Accuracy Euclidean Distance:	100.00
#
#
# 2021-03-11 13:56:44 - Evaluating model
# 2021-03-11 13:56:44 - Load pretrained SentenceTransformer: output/CovidFAQ/models/triplet_simple_faq_1.1
# 2021-03-11 13:56:44 - Load SentenceTransformer from folder: output/CovidFAQ/models/triplet_simple_faq_1.1
# 2021-03-11 13:56:45 - Use pytorch device: cuda
# 2021-03-11 13:56:45 - TripletEvaluator: Evaluating the model on test dataset:
# 2021-03-11 13:56:46 - Accuracy Cosine Distance:   	98.77
# 2021-03-11 13:56:46 - Accuracy Manhatten Distance:	98.77
# 2021-03-11 13:56:46 - Accuracy Euclidean Distance:	98.77

# %% [markdown]
# **query_type=user_query, neg_type="hard"**

# %%
# load hard_user_query_dataset.csv
hard_user_query_dataset = pd.read_csv('data/CovidFAQ/dataset/triplet/user_query/hard_user_query_dataset.csv')
hard_user_query_dataset
# Out:
#                               question  ...                                           negative
# 0                   What is COVID-19?   ...  All 50 states in the U.S., as well as D.C., Pu...
# 1                   What is COVID-19?   ...  SARS-CoV-2 refers to the virus that causes COV...
# 2                   What is COVID-19?   ...  Most people with mild coronavirus illness will...
# 3                   What is COVID-19?   ...  Social distancing is one of the most effective...
# 4                   What is COVID-19?   ...  MERs is Middle East Respiratory Syndrome. It i...
# ...                                ...  ...                                                ...
# 34607  world coronavirus die in summer  ...  It is important to stay calm and put your prep...
# 34608  world coronavirus die in summer  ...  There is currently no evidence to suggest that...
# 34609  world coronavirus die in summer  ...  Flattening the curve refers to the use of soci...
# 34610  world coronavirus die in summer  ...  This interactive map by the Johns Hopkins Univ...
# 34611  world coronavirus die in summer  ...  It was first found in Wuhan City, Hubei Provin...
#
# [34612 rows x 3 columns]

# %%
hard_user_query_dataset.shape
# Out:
# (34612, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_hard_user_query = FAQ_BERT_Finetuning(
    loss_type="triplet", query_type='user_query', neg_type='hard', version="1.1", epochs=4, batch_size=16, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_hard_user_query.create_model(hard_user_query_dataset, output_path)
# Out:
# 2021-03-11 13:57:46 - Use pytorch device: cuda
# 2021-03-11 13:57:46 - Generating directory structure
# 2021-03-11 13:57:46 - Generating triplets for training
# 2021-03-11 13:57:49 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=4.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=1731.0, style=ProgressStyle(description_w…
# 2021-03-11 14:01:44 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 1000 steps:
# 2021-03-11 14:01:58 - Accuracy Cosine Distance:   	99.57
# 2021-03-11 14:01:58 - Accuracy Manhatten Distance:	99.60
# 2021-03-11 14:01:58 - Accuracy Euclidean Distance:	99.57
#
# 2021-03-11 14:01:58 - Save model to output/CovidFAQ/models/triplet_hard_user_query_1.1
#
# 2021-03-11 14:04:50 - TripletEvaluator: Evaluating the model on val dataset after epoch 0:
# 2021-03-11 14:05:05 - Accuracy Cosine Distance:   	99.42
# 2021-03-11 14:05:05 - Accuracy Manhatten Distance:	99.39
# 2021-03-11 14:05:05 - Accuracy Euclidean Distance:	99.36
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=1731.0, style=ProgressStyle(description_w…
# 2021-03-11 14:08:59 - TripletEvaluator: Evaluating the model on val dataset in epoch 1 after 1000 steps:
# 2021-03-11 14:09:13 - Accuracy Cosine Distance:   	99.80
# 2021-03-11 14:09:13 - Accuracy Manhatten Distance:	99.74
# 2021-03-11 14:09:13 - Accuracy Euclidean Distance:	99.77
#
# 2021-03-11 14:09:13 - Save model to output/CovidFAQ/models/triplet_hard_user_query_1.1
#
# 2021-03-11 14:12:05 - TripletEvaluator: Evaluating the model on val dataset after epoch 1:
# 2021-03-11 14:12:19 - Accuracy Cosine Distance:   	99.88
# 2021-03-11 14:12:19 - Accuracy Manhatten Distance:	99.83
# 2021-03-11 14:12:19 - Accuracy Euclidean Distance:	99.83
#
# 2021-03-11 14:12:19 - Save model to output/CovidFAQ/models/triplet_hard_user_query_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=1731.0, style=ProgressStyle(description_w…
# 2021-03-11 14:16:15 - TripletEvaluator: Evaluating the model on val dataset in epoch 2 after 1000 steps:
# 2021-03-11 14:16:29 - Accuracy Cosine Distance:   	99.83
# 2021-03-11 14:16:29 - Accuracy Manhatten Distance:	99.80
# 2021-03-11 14:16:29 - Accuracy Euclidean Distance:	99.83
#
#
# 2021-03-11 14:19:20 - TripletEvaluator: Evaluating the model on val dataset after epoch 2:
# 2021-03-11 14:19:35 - Accuracy Cosine Distance:   	99.80
# 2021-03-11 14:19:35 - Accuracy Manhatten Distance:	99.77
# 2021-03-11 14:19:35 - Accuracy Euclidean Distance:	99.80
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=1731.0, style=ProgressStyle(description_w…
# 2021-03-11 14:23:29 - TripletEvaluator: Evaluating the model on val dataset in epoch 3 after 1000 steps:
# 2021-03-11 14:23:43 - Accuracy Cosine Distance:   	99.91
# 2021-03-11 14:23:43 - Accuracy Manhatten Distance:	99.86
# 2021-03-11 14:23:43 - Accuracy Euclidean Distance:	99.86
#
# 2021-03-11 14:23:43 - Save model to output/CovidFAQ/models/triplet_hard_user_query_1.1
#
# 2021-03-11 14:26:36 - TripletEvaluator: Evaluating the model on val dataset after epoch 3:
# 2021-03-11 14:26:50 - Accuracy Cosine Distance:   	99.91
# 2021-03-11 14:26:50 - Accuracy Manhatten Distance:	99.86
# 2021-03-11 14:26:50 - Accuracy Euclidean Distance:	99.88
#
#
# 2021-03-11 14:26:50 - Evaluating model
# 2021-03-11 14:26:50 - Load pretrained SentenceTransformer: output/CovidFAQ/models/triplet_hard_user_query_1.1
# 2021-03-11 14:26:50 - Load SentenceTransformer from folder: output/CovidFAQ/models/triplet_hard_user_query_1.1
# 2021-03-11 14:26:52 - Use pytorch device: cuda
# 2021-03-11 14:26:52 - TripletEvaluator: Evaluating the model on test dataset:
# 2021-03-11 14:27:06 - Accuracy Cosine Distance:   	99.86
# 2021-03-11 14:27:06 - Accuracy Manhatten Distance:	99.86
# 2021-03-11 14:27:06 - Accuracy Euclidean Distance:	99.86

# %% [markdown]
# **query_type=user_query, neg_type="simple"**

# %%
# load simple_user_query_dataset.csv
simple_user_query_dataset = pd.read_csv('data/CovidFAQ/dataset/triplet/user_query/simple_user_query_dataset.csv')
simple_user_query_dataset
# Out:
#                                question  ...                                           negative
# 0      What does Corona and Covid mean?  ...  The best way to prevent illness from COVID-19 ...
# 1      What does Corona and Covid mean?  ...  A recent study shows that the virus can live i...
# 2      What does Corona and Covid mean?  ...  It is able to spread person-to-person. The spr...
# 3      What does Corona and Covid mean?  ...  It was first found in Wuhan City, Hubei Provin...
# 4      What does Corona and Covid mean?  ...  A novel, or new, coronavirus is one that has n...
# ...                                 ...  ...                                                ...
# 33283   world coronavirus die in summer  ...  Right now, our current understanding of how CO...
# 33284   world coronavirus die in summer  ...  This interactive map by the Johns Hopkins Univ...
# 33285   world coronavirus die in summer  ...  If you have the symptoms of COVID-19 and want ...
# 33286   world coronavirus die in summer  ...  Yes, all states have reported COVID-19 infecti...
# 33287   world coronavirus die in summer  ...  This interactive map by the Johns Hopkins Univ...
#
# [33288 rows x 3 columns]

# %%
simple_user_query_dataset.shape
# Out:
# (33288, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_simple_user_query = FAQ_BERT_Finetuning(
    loss_type="triplet", query_type='user_query', neg_type='simple', version="1.1", epochs=4, batch_size=16, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_simple_user_query.create_model(simple_user_query_dataset, output_path)
# Out:
# 2021-03-11 14:29:32 - Use pytorch device: cuda
# 2021-03-11 14:29:32 - Generating directory structure
# 2021-03-11 14:29:32 - Generating triplets for training
# 2021-03-11 14:29:34 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=4.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=1665.0, style=ProgressStyle(description_w…
# 2021-03-11 14:33:28 - TripletEvaluator: Evaluating the model on val dataset in epoch 0 after 1000 steps:
# 2021-03-11 14:33:41 - Accuracy Cosine Distance:   	91.44
# 2021-03-11 14:33:41 - Accuracy Manhatten Distance:	91.50
# 2021-03-11 14:33:41 - Accuracy Euclidean Distance:	91.50
#
# 2021-03-11 14:33:41 - Save model to output/CovidFAQ/models/triplet_simple_user_query_1.1
#
# 2021-03-11 14:36:18 - TripletEvaluator: Evaluating the model on val dataset after epoch 0:
# 2021-03-11 14:36:32 - Accuracy Cosine Distance:   	91.68
# 2021-03-11 14:36:32 - Accuracy Manhatten Distance:	91.74
# 2021-03-11 14:36:32 - Accuracy Euclidean Distance:	91.74
#
# 2021-03-11 14:36:32 - Save model to output/CovidFAQ/models/triplet_simple_user_query_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=1665.0, style=ProgressStyle(description_w…
# 2021-03-11 14:40:26 - TripletEvaluator: Evaluating the model on val dataset in epoch 1 after 1000 steps:
# 2021-03-11 14:40:40 - Accuracy Cosine Distance:   	92.07
# 2021-03-11 14:40:40 - Accuracy Manhatten Distance:	92.04
# 2021-03-11 14:40:40 - Accuracy Euclidean Distance:	92.04
#
# 2021-03-11 14:40:40 - Save model to output/CovidFAQ/models/triplet_simple_user_query_1.1
#
# 2021-03-11 14:43:16 - TripletEvaluator: Evaluating the model on val dataset after epoch 1:
# 2021-03-11 14:43:30 - Accuracy Cosine Distance:   	91.95
# 2021-03-11 14:43:30 - Accuracy Manhatten Distance:	92.01
# 2021-03-11 14:43:30 - Accuracy Euclidean Distance:	92.01
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=1665.0, style=ProgressStyle(description_w…
# 2021-03-11 14:47:23 - TripletEvaluator: Evaluating the model on val dataset in epoch 2 after 1000 steps:
# 2021-03-11 14:47:37 - Accuracy Cosine Distance:   	92.10
# 2021-03-11 14:47:37 - Accuracy Manhatten Distance:	92.07
# 2021-03-11 14:47:37 - Accuracy Euclidean Distance:	92.07
#
# 2021-03-11 14:47:37 - Save model to output/CovidFAQ/models/triplet_simple_user_query_1.1
#
# 2021-03-11 14:50:14 - TripletEvaluator: Evaluating the model on val dataset after epoch 2:
# 2021-03-11 14:50:28 - Accuracy Cosine Distance:   	92.13
# 2021-03-11 14:50:28 - Accuracy Manhatten Distance:	92.25
# 2021-03-11 14:50:28 - Accuracy Euclidean Distance:	92.25
#
# 2021-03-11 14:50:28 - Save model to output/CovidFAQ/models/triplet_simple_user_query_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=1665.0, style=ProgressStyle(description_w…
# 2021-03-11 14:54:22 - TripletEvaluator: Evaluating the model on val dataset in epoch 3 after 1000 steps:
# 2021-03-11 14:54:36 - Accuracy Cosine Distance:   	92.34
# 2021-03-11 14:54:36 - Accuracy Manhatten Distance:	92.22
# 2021-03-11 14:54:36 - Accuracy Euclidean Distance:	92.34
#
# 2021-03-11 14:54:36 - Save model to output/CovidFAQ/models/triplet_simple_user_query_1.1
#
# 2021-03-11 14:57:13 - TripletEvaluator: Evaluating the model on val dataset after epoch 3:
# 2021-03-11 14:57:26 - Accuracy Cosine Distance:   	92.22
# 2021-03-11 14:57:26 - Accuracy Manhatten Distance:	92.28
# 2021-03-11 14:57:26 - Accuracy Euclidean Distance:	92.28
#
#
# 2021-03-11 14:57:26 - Evaluating model
# 2021-03-11 14:57:26 - Load pretrained SentenceTransformer: output/CovidFAQ/models/triplet_simple_user_query_1.1
# 2021-03-11 14:57:26 - Load SentenceTransformer from folder: output/CovidFAQ/models/triplet_simple_user_query_1.1
# 2021-03-11 14:57:28 - Use pytorch device: cuda
# 2021-03-11 14:57:28 - TripletEvaluator: Evaluating the model on test dataset:
# 2021-03-11 14:57:42 - Accuracy Cosine Distance:   	91.62
# 2021-03-11 14:57:42 - Accuracy Manhatten Distance:	91.50
# 2021-03-11 14:57:42 - Accuracy Euclidean Distance:	91.59

# %% [markdown]
# **BERT-Finetuning with Softmax Loss**

# %% [markdown]
# **query_type=faq, neg_type="hard"**

# %%
# load hard_faq_dataset.csv
hard_faq_dataset = pd.read_csv('data/CovidFAQ/dataset/softmax/faq/hard_faq_dataset.csv')
hard_faq_dataset
# Out:
#       label  ...                                             answer
# 0         1  ...  COVID-19 is a new coronavirus that we have not...
# 1         1  ...  Coronavirus are a type of virus - there are ma...
# 2         1  ...  Currently, there is no evidence of food or foo...
# 3         1  ...  Socially distancing is a practice that aims to...
# 4         1  ...  Social distancing is one of the most effective...
# ...     ...  ...                                                ...
# 3082      0  ...  COVID-19 is being spread through respiratory d...
# 3083      0  ...  It is able to spread person-to-person. The spr...
# 3084      0  ...  The best way to prevent illness from COVID-19 ...
# 3085      0  ...  Masks are only helpful in preventing people wh...
# 3086      0  ...  You should quarantine yourself for at least 14...
#
# [3087 rows x 3 columns]

# %%
# check dataset shape
hard_faq_dataset.shape
# Out:
# (3087, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_hard_faq = FAQ_BERT_Finetuning(
    loss_type="softmax", query_type='faq', neg_type='hard', version="1.1", epochs=4, batch_size=16, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_hard_faq.create_model(hard_faq_dataset, output_path)
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2021-03-11 14:58:22 - Use pytorch device: cuda
# 2021-03-11 14:58:22 - Generating directory structure
# 2021-03-11 14:58:22 - Generating triplets for training
# 2021-03-11 14:58:22 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=4.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=155.0, style=ProgressStyle(description_wi…
# 2021-03-11 14:58:59 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 0:
# 2021-03-11 14:59:00 - Accuracy:           94.50	(Threshold: 0.9810)
# 2021-03-11 14:59:00 - F1:                 93.63	(Threshold: 0.3096)
# 2021-03-11 14:59:00 - Precision:          96.90
# 2021-03-11 14:59:00 - Recall:             90.58
# 2021-03-11 14:59:00 - Average Precision:  96.65
#
# 2021-03-11 14:59:00 - Save model to output/CovidFAQ/models/softmax_hard_faq_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=155.0, style=ProgressStyle(description_wi…
# 2021-03-11 14:59:38 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 1:
# 2021-03-11 14:59:40 - Accuracy:           94.82	(Threshold: 0.9951)
# 2021-03-11 14:59:40 - F1:                 93.85	(Threshold: 0.9951)
# 2021-03-11 14:59:40 - Precision:          100.00
# 2021-03-11 14:59:40 - Recall:             88.41
# 2021-03-11 14:59:40 - Average Precision:  97.52
#
# 2021-03-11 14:59:40 - Save model to output/CovidFAQ/models/softmax_hard_faq_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=155.0, style=ProgressStyle(description_wi…
# 2021-03-11 15:00:17 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 2:
# 2021-03-11 15:00:19 - Accuracy:           95.47	(Threshold: 0.3552)
# 2021-03-11 15:00:19 - F1:                 94.74	(Threshold: 0.3552)
# 2021-03-11 15:00:19 - Precision:          98.44
# 2021-03-11 15:00:19 - Recall:             91.30
# 2021-03-11 15:00:19 - Average Precision:  97.76
#
# 2021-03-11 15:00:19 - Save model to output/CovidFAQ/models/softmax_hard_faq_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=155.0, style=ProgressStyle(description_wi…
# 2021-03-11 15:00:57 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 3:
# 2021-03-11 15:00:58 - Accuracy:           95.79	(Threshold: 0.0598)
# 2021-03-11 15:00:58 - F1:                 95.20	(Threshold: 0.0537)
# 2021-03-11 15:00:58 - Precision:          96.99
# 2021-03-11 15:00:58 - Recall:             93.48
# 2021-03-11 15:00:58 - Average Precision:  97.74
#
#
# 2021-03-11 15:00:58 - Evaluating model
# 2021-03-11 15:01:00 - Use pytorch device: cuda
# 2021-03-11 15:01:00 - CEBinaryClassificationEvaluator: Evaluating the model on test dataset:
# 2021-03-11 15:01:01 - Accuracy:           98.38	(Threshold: 0.4471)
# 2021-03-11 15:01:01 - F1:                 98.32	(Threshold: 0.4471)
# 2021-03-11 15:01:01 - Precision:          99.32
# 2021-03-11 15:01:01 - Recall:             97.33
# 2021-03-11 15:01:01 - Average Precision:  99.19

# %% [markdown]
# **query_type=faq, neg_type="simple"**

# %%
# load simple_faq_dataset.csv
simple_faq_dataset = pd.read_csv('data/CovidFAQ/dataset/softmax/faq/simple_faq_dataset.csv')
simple_faq_dataset
# Out:
#       label  ...                                             answer
# 0         1  ...  COVID-19 is a new coronavirus that we have not...
# 1         1  ...  Coronavirus are a type of virus - there are ma...
# 2         1  ...  Currently, there is no evidence of food or foo...
# 3         1  ...  Socially distancing is a practice that aims to...
# 4         1  ...  Social distancing is one of the most effective...
# ...     ...  ...                                                ...
# 1695      0  ...  Experts believe that this is posisble, though ...
# 1696      0  ...  Reported illnesses have ranged from mild sympt...
# 1697      0  ...  If you have developed symptoms like fever, cou...
# 1698      0  ...  Face masks, including fabric ones, are only re...
# 1699      0  ...  Right now, our current understanding of how CO...
#
# [1700 rows x 3 columns]

# %%
simple_faq_dataset.shape
# Out:
# (1700, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_simple_faq = FAQ_BERT_Finetuning(
    loss_type="softmax", query_type='faq', neg_type='simple', version="1.1", epochs=4, batch_size=16, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_simple_faq.create_model(simple_faq_dataset, output_path)
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2021-03-11 15:01:46 - Use pytorch device: cuda
# 2021-03-11 15:01:46 - Generating directory structure
# 2021-03-11 15:01:46 - Generating triplets for training
# 2021-03-11 15:01:46 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=4.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=85.0, style=ProgressStyle(description_wid…
# 2021-03-11 15:02:06 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 0:
# 2021-03-11 15:02:07 - Accuracy:           94.71	(Threshold: 0.0278)
# 2021-03-11 15:02:07 - F1:                 9.20	(Threshold: 0.0268)
# 2021-03-11 15:02:07 - Precision:          4.82
# 2021-03-11 15:02:07 - Recall:             100.00
# 2021-03-11 15:02:07 - Average Precision:  3.42
#
# 2021-03-11 15:02:07 - Save model to output/CovidFAQ/models/softmax_simple_faq_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=85.0, style=ProgressStyle(description_wid…
# 2021-03-11 15:02:28 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 1:
# 2021-03-11 15:02:29 - Accuracy:           94.71	(Threshold: 0.0331)
# 2021-03-11 15:02:29 - F1:                 9.20	(Threshold: 0.0312)
# 2021-03-11 15:02:29 - Precision:          4.82
# 2021-03-11 15:02:29 - Recall:             100.00
# 2021-03-11 15:02:29 - Average Precision:  3.27
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=85.0, style=ProgressStyle(description_wid…
# 2021-03-11 15:02:49 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 2:
# 2021-03-11 15:02:49 - Accuracy:           94.71	(Threshold: 0.0290)
# 2021-03-11 15:02:49 - F1:                 9.20	(Threshold: 0.0267)
# 2021-03-11 15:02:49 - Precision:          4.82
# 2021-03-11 15:02:49 - Recall:             100.00
# 2021-03-11 15:02:49 - Average Precision:  3.14
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=85.0, style=ProgressStyle(description_wid…
# 2021-03-11 15:03:09 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 3:
# 2021-03-11 15:03:10 - Accuracy:           94.71	(Threshold: 0.0332)
# 2021-03-11 15:03:10 - F1:                 9.20	(Threshold: 0.0302)
# 2021-03-11 15:03:10 - Precision:          4.82
# 2021-03-11 15:03:10 - Recall:             100.00
# 2021-03-11 15:03:10 - Average Precision:  3.11
#
#
# 2021-03-11 15:03:10 - Evaluating model
# 2021-03-11 15:03:12 - Use pytorch device: cuda
# 2021-03-11 15:03:12 - CEBinaryClassificationEvaluator: Evaluating the model on test dataset:
# 2021-03-11 15:03:13 - Accuracy:           92.35	(Threshold: 0.0278)
# 2021-03-11 15:03:13 - F1:                 12.90	(Threshold: 0.0274)
# 2021-03-11 15:03:13 - Precision:          6.99
# 2021-03-11 15:03:13 - Recall:             83.33
# 2021-03-11 15:03:13 - Average Precision:  6.37

# %% [markdown]
# **query_type=user_query, neg_type="hard"**

# %%
# load hard_user_query_dataset.csv
hard_user_query_dataset = pd.read_csv('data/CovidFAQ/dataset/softmax/user_query/hard_user_query_dataset.csv')
hard_user_query_dataset
# Out:
#        label  ...                                             answer
# 0          1  ...  COVID-19 is a new coronavirus that we have not...
# 1          1  ...  Coronavirus are a type of virus - there are ma...
# 2          1  ...  Currently, there is no evidence of food or foo...
# 3          1  ...  Socially distancing is a practice that aims to...
# 4          1  ...  Social distancing is one of the most effective...
# ...      ...  ...                                                ...
# 28598      0  ...  It is important to stay calm and put your prep...
# 28599      0  ...  There is currently no evidence to suggest that...
# 28600      0  ...  Flattening the curve refers to the use of soci...
# 28601      0  ...  This interactive map by the Johns Hopkins Univ...
# 28602      0  ...  It was first found in Wuhan City, Hubei Provin...
#
# [28603 rows x 3 columns]

# %%
hard_user_query_dataset.shape
# Out:
# (28603, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_hard_user_query = FAQ_BERT_Finetuning(
    loss_type="softmax", query_type='user_query', neg_type='hard', version="1.1", epochs=4, batch_size=16, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_hard_user_query.create_model(hard_user_query_dataset, output_path)
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2021-03-11 15:03:48 - Use pytorch device: cuda
# 2021-03-11 15:03:48 - Generating directory structure
# 2021-03-11 15:03:48 - Generating triplets for training
# 2021-03-11 15:03:50 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=4.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=1431.0, style=ProgressStyle(description_w…
# 2021-03-11 15:07:53 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset in epoch 0 after 1000 steps:
# 2021-03-11 15:08:07 - Accuracy:           96.50	(Threshold: 0.0749)
# 2021-03-11 15:08:07 - F1:                 59.38	(Threshold: 0.0408)
# 2021-03-11 15:08:07 - Precision:          70.37
# 2021-03-11 15:08:07 - Recall:             51.35
# 2021-03-11 15:08:07 - Average Precision:  57.52
#
# 2021-03-11 15:08:07 - Save model to output/CovidFAQ/models/softmax_hard_user_query_1.1
#
# 2021-03-11 15:09:53 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 0:
# 2021-03-11 15:10:07 - Accuracy:           96.75	(Threshold: 0.9094)
# 2021-03-11 15:10:07 - F1:                 64.23	(Threshold: 0.1398)
# 2021-03-11 15:10:07 - Precision:          69.84
# 2021-03-11 15:10:07 - Recall:             59.46
# 2021-03-11 15:10:07 - Average Precision:  63.45
#
# 2021-03-11 15:10:07 - Save model to output/CovidFAQ/models/softmax_hard_user_query_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=1431.0, style=ProgressStyle(description_w…
# 2021-03-11 15:14:11 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset in epoch 1 after 1000 steps:
# 2021-03-11 15:14:25 - Accuracy:           97.20	(Threshold: 0.8016)
# 2021-03-11 15:14:25 - F1:                 71.38	(Threshold: 0.1400)
# 2021-03-11 15:14:25 - Precision:          71.14
# 2021-03-11 15:14:25 - Recall:             71.62
# 2021-03-11 15:14:25 - Average Precision:  72.86
#
# 2021-03-11 15:14:25 - Save model to output/CovidFAQ/models/softmax_hard_user_query_1.1
#
# 2021-03-11 15:16:10 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 1:
# 2021-03-11 15:16:25 - Accuracy:           97.45	(Threshold: 0.1309)
# 2021-03-11 15:16:25 - F1:                 73.45	(Threshold: 0.1309)
# 2021-03-11 15:16:25 - Precision:          79.53
# 2021-03-11 15:16:25 - Recall:             68.24
# 2021-03-11 15:16:25 - Average Precision:  74.37
#
# 2021-03-11 15:16:25 - Save model to output/CovidFAQ/models/softmax_hard_user_query_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=1431.0, style=ProgressStyle(description_w…
# 2021-03-11 15:20:30 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset in epoch 2 after 1000 steps:
# 2021-03-11 15:20:44 - Accuracy:           97.59	(Threshold: 0.3457)
# 2021-03-11 15:20:44 - F1:                 75.09	(Threshold: 0.2064)
# 2021-03-11 15:20:44 - Precision:          80.62
# 2021-03-11 15:20:44 - Recall:             70.27
# 2021-03-11 15:20:44 - Average Precision:  77.63
#
# 2021-03-11 15:20:44 - Save model to output/CovidFAQ/models/softmax_hard_user_query_1.1
#
# 2021-03-11 15:22:29 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 2:
# 2021-03-11 15:22:43 - Accuracy:           97.66	(Threshold: 0.7517)
# 2021-03-11 15:22:43 - F1:                 76.57	(Threshold: 0.0811)
# 2021-03-11 15:22:43 - Precision:          74.84
# 2021-03-11 15:22:43 - Recall:             78.38
# 2021-03-11 15:22:43 - Average Precision:  77.96
#
# 2021-03-11 15:22:43 - Save model to output/CovidFAQ/models/softmax_hard_user_query_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=1431.0, style=ProgressStyle(description_w…
# 2021-03-11 15:26:47 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset in epoch 3 after 1000 steps:
# 2021-03-11 15:27:01 - Accuracy:           97.69	(Threshold: 0.4044)
# 2021-03-11 15:27:01 - F1:                 76.76	(Threshold: 0.4044)
# 2021-03-11 15:27:01 - Precision:          80.15
# 2021-03-11 15:27:01 - Recall:             73.65
# 2021-03-11 15:27:01 - Average Precision:  78.99
#
# 2021-03-11 15:27:01 - Save model to output/CovidFAQ/models/softmax_hard_user_query_1.1
#
# 2021-03-11 15:28:47 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 3:
# 2021-03-11 15:29:01 - Accuracy:           97.69	(Threshold: 0.8732)
# 2021-03-11 15:29:01 - F1:                 77.13	(Threshold: 0.0827)
# 2021-03-11 15:29:01 - Precision:          77.93
# 2021-03-11 15:29:01 - Recall:             76.35
# 2021-03-11 15:29:01 - Average Precision:  79.34
#
# 2021-03-11 15:29:01 - Save model to output/CovidFAQ/models/softmax_hard_user_query_1.1
#
# 2021-03-11 15:29:02 - Evaluating model
# 2021-03-11 15:29:04 - Use pytorch device: cuda
# 2021-03-11 15:29:04 - CEBinaryClassificationEvaluator: Evaluating the model on test dataset:
# 2021-03-11 15:29:19 - Accuracy:           98.32	(Threshold: 0.3042)
# 2021-03-11 15:29:19 - F1:                 80.49	(Threshold: 0.3042)
# 2021-03-11 15:29:19 - Precision:          86.84
# 2021-03-11 15:29:19 - Recall:             75.00
# 2021-03-11 15:29:19 - Average Precision:  79.81

# %% [markdown]
# **query_type=user_query, neg_type="simple"**

# %%
# load simple_user_query_dataset.csv
simple_user_query_dataset = pd.read_csv('data/CovidFAQ/dataset/softmax/user_query/simple_user_query_dataset.csv')
simple_user_query_dataset
# Out:
#        label  ...                                             answer
# 0          1  ...  COVID-19 is a new coronavirus that we have not...
# 1          1  ...  Coronavirus are a type of virus - there are ma...
# 2          1  ...  Currently, there is no evidence of food or foo...
# 3          1  ...  COVID-19 is a new coronavirus that we have not...
# 4          1  ...  COVID-19 is a new coronavirus that we have not...
# ...      ...  ...                                                ...
# 34670      0  ...  Right now, our current understanding of how CO...
# 34671      0  ...  This interactive map by the Johns Hopkins Univ...
# 34672      0  ...  If you have the symptoms of COVID-19 and want ...
# 34673      0  ...  Yes, all states have reported COVID-19 infecti...
# 34674      0  ...  This interactive map by the Johns Hopkins Univ...
#
# [34675 rows x 3 columns]

# %%
simple_user_query_dataset.shape
# Out:
# (34675, 3)

# %%
# create instance of FAQ_BERT_Finetuning
bert_simple_user_query = FAQ_BERT_Finetuning(
    loss_type="softmax", query_type='user_query', neg_type='simple', version="1.1", epochs=4, batch_size=16, 
    pre_trained_name='distilbert-base-uncased', 
    evaluation_steps=1000, test_size=0.2
)

# create model and save to output path
bert_simple_user_query.create_model(simple_user_query_dataset, output_path)
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2021-03-11 15:30:00 - Use pytorch device: cuda
# 2021-03-11 15:30:00 - Generating directory structure
# 2021-03-11 15:30:00 - Generating triplets for training
# 2021-03-11 15:30:02 - Training model
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=4.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=1734.0, style=ProgressStyle(description_w…
# 2021-03-11 15:33:42 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset in epoch 0 after 1000 steps:
# 2021-03-11 15:33:57 - Accuracy:           95.93	(Threshold: 0.2398)
# 2021-03-11 15:33:57 - F1:                 28.49	(Threshold: 0.1203)
# 2021-03-11 15:33:57 - Precision:          23.92
# 2021-03-11 15:33:57 - Recall:             35.21
# 2021-03-11 15:33:57 - Average Precision:  17.90
#
# 2021-03-11 15:33:57 - Save model to output/CovidFAQ/models/softmax_simple_user_query_1.1
#
# 2021-03-11 15:36:40 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 0:
# 2021-03-11 15:36:55 - Accuracy:           96.05	(Threshold: 0.4448)
# 2021-03-11 15:36:55 - F1:                 35.68	(Threshold: 0.1145)
# 2021-03-11 15:36:55 - Precision:          26.76
# 2021-03-11 15:36:55 - Recall:             53.52
# 2021-03-11 15:36:55 - Average Precision:  30.32
#
# 2021-03-11 15:36:55 - Save model to output/CovidFAQ/models/softmax_simple_user_query_1.1
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=1734.0, style=ProgressStyle(description_w…
# 2021-03-11 15:40:36 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset in epoch 1 after 1000 steps:
# 2021-03-11 15:40:52 - Accuracy:           96.16	(Threshold: 0.5028)
# 2021-03-11 15:40:52 - F1:                 39.06	(Threshold: 0.1410)
# 2021-03-11 15:40:52 - Precision:          37.42
# 2021-03-11 15:40:52 - Recall:             40.85
# 2021-03-11 15:40:52 - Average Precision:  35.67
#
# 2021-03-11 15:40:52 - Save model to output/CovidFAQ/models/softmax_simple_user_query_1.1
#
# 2021-03-11 15:43:33 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 1:
# 2021-03-11 15:43:48 - Accuracy:           96.08	(Threshold: 0.5158)
# 2021-03-11 15:43:48 - F1:                 40.61	(Threshold: 0.3395)
# 2021-03-11 15:43:48 - Precision:          44.54
# 2021-03-11 15:43:48 - Recall:             37.32
# 2021-03-11 15:43:48 - Average Precision:  35.29
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=1734.0, style=ProgressStyle(description_w…
# 2021-03-11 15:47:27 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset in epoch 2 after 1000 steps:
# 2021-03-11 15:47:42 - Accuracy:           96.16	(Threshold: 0.5148)
# 2021-03-11 15:47:42 - F1:                 40.80	(Threshold: 0.1776)
# 2021-03-11 15:47:42 - Precision:          38.85
# 2021-03-11 15:47:42 - Recall:             42.96
# 2021-03-11 15:47:42 - Average Precision:  37.11
#
# 2021-03-11 15:47:42 - Save model to output/CovidFAQ/models/softmax_simple_user_query_1.1
#
# 2021-03-11 15:50:24 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 2:
# 2021-03-11 15:50:39 - Accuracy:           96.16	(Threshold: 0.5699)
# 2021-03-11 15:50:39 - F1:                 39.73	(Threshold: 0.2282)
# 2021-03-11 15:50:39 - Precision:          38.06
# 2021-03-11 15:50:39 - Recall:             41.55
# 2021-03-11 15:50:39 - Average Precision:  35.28
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=1734.0, style=ProgressStyle(description_w…
# 2021-03-11 15:54:18 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset in epoch 3 after 1000 steps:
# 2021-03-11 15:54:33 - Accuracy:           96.16	(Threshold: 0.5448)
# 2021-03-11 15:54:33 - F1:                 39.38	(Threshold: 0.1748)
# 2021-03-11 15:54:33 - Precision:          34.97
# 2021-03-11 15:54:33 - Recall:             45.07
# 2021-03-11 15:54:33 - Average Precision:  35.44
#
#
# 2021-03-11 15:57:14 - CEBinaryClassificationEvaluator: Evaluating the model on  dataset after epoch 3:
# 2021-03-11 15:57:30 - Accuracy:           96.16	(Threshold: 0.4873)
# 2021-03-11 15:57:30 - F1:                 39.19	(Threshold: 0.0324)
# 2021-03-11 15:57:30 - Precision:          26.49
# 2021-03-11 15:57:30 - Recall:             75.35
# 2021-03-11 15:57:30 - Average Precision:  35.24
#
#
# 2021-03-11 15:57:30 - Evaluating model
# 2021-03-11 15:57:32 - Use pytorch device: cuda
# 2021-03-11 15:57:32 - CEBinaryClassificationEvaluator: Evaluating the model on test dataset:
# 2021-03-11 15:57:47 - Accuracy:           95.27	(Threshold: 0.6221)
# 2021-03-11 15:57:47 - F1:                 42.74	(Threshold: 0.1558)
# 2021-03-11 15:57:47 - Precision:          41.67
# 2021-03-11 15:57:47 - Recall:             43.86
# 2021-03-11 15:57:47 - Average Precision:  38.23
