# %%
# !pip3 install elasticsearch
# Out:
# Requirement already satisfied: elasticsearch in /Users/nattiya/miniconda3/envs/dl/lib/python3.8/site-packages (7.9.1)
# Requirement already satisfied: urllib3>=1.21.1 in /Users/nattiya/miniconda3/envs/dl/lib/python3.8/site-packages (from elasticsearch) (1.25.10)
# Requirement already satisfied: certifi in /Users/nattiya/miniconda3/envs/dl/lib/python3.8/site-packages (from elasticsearch) (2020.12.5)

# %%
# !pip3 install elasticsearch-dsl
# Out:
# Requirement already satisfied: elasticsearch-dsl in /Users/nattiya/miniconda3/envs/dl/lib/python3.8/site-packages (7.3.0)
# Requirement already satisfied: six in /Users/nattiya/miniconda3/envs/dl/lib/python3.8/site-packages (from elasticsearch-dsl) (1.15.0)
# Requirement already satisfied: python-dateutil in /Users/nattiya/miniconda3/envs/dl/lib/python3.8/site-packages (from elasticsearch-dsl) (2.8.1)
# Requirement already satisfied: elasticsearch<8.0.0,>=7.0.0 in /Users/nattiya/miniconda3/envs/dl/lib/python3.8/site-packages (from elasticsearch-dsl) (7.9.1)
# Requirement already satisfied: certifi in /Users/nattiya/miniconda3/envs/dl/lib/python3.8/site-packages (from elasticsearch<8.0.0,>=7.0.0->elasticsearch-dsl) (2020.12.5)
# Requirement already satisfied: urllib3>=1.21.1 in /Users/nattiya/miniconda3/envs/dl/lib/python3.8/site-packages (from elasticsearch<8.0.0,>=7.0.0->elasticsearch-dsl) (1.25.10)

# %%
import sys
sys.path.insert(0, '../../../BERT-FAQ/')

# import required libraries
from elasticsearch_dsl import Index, Document, Integer, Text, analyzer, Keyword, Double
from elasticsearch_dsl.connections import connections
from elasticsearch import Elasticsearch, helpers

from evaluation import get_relevance_label_df
from shared.utils import load_from_json
from shared.utils import dump_to_json
from shared.utils import make_dirs
from indexer import ingest_data
from indexer import QA
import logging

# %%
# get list of query answer pairs

query_answer_pairs_filepath = '../../../BERT-FAQ/data/CovidFAQ/query_answer_pairs.json'
relevance_label_df = get_relevance_label_df(query_answer_pairs_filepath)
faq_qa_pair_df = relevance_label_df[relevance_label_df['query_type'] == 'faq']
faq_qa_pairs = faq_qa_pair_df.T.to_dict().values()

# %%
# check relevance_label_df
relevance_label_df
# Out:
#       label  query_type                                           question  \
# 0         1         faq                                 What is COVID-19?
# 1         1         faq                             What is a coronavirus?
# 2         1         faq  Any advice about how to minimize risk during g...
# 3         1         faq                     Why do I have to stay at home?
# 4         1         faq  What is social distancing and how does it help...
# ...     ...         ...                                                ...
# 1450      1  user_query                    will coronavirus stop in summer
# 1451      1  user_query                will coronavirus stop in the summer
# 1452      1  user_query             will coronavirus survive in the summer
# 1453      1  user_query               will coronavirus survive on surfaces
# 1454      1  user_query                    world coronavirus die in summer
#
#                                                  answer    id
# 0     COVID-19 is a new coronavirus that we have not...     1
# 1     Coronavirus are a type of virus - there are ma...     2
# 2     Currently, there is no evidence of food or foo...     3
# 3     Socially distancing is a practice that aims to...     4
# 4     Social distancing is one of the most effective...     5
# ...                                                 ...   ...
# 1450  We do not know. Some viruses, like the common ...  1451
# 1451  We do not know. Some viruses, like the common ...  1452
# 1452  We do not know. Some viruses, like the common ...  1453
# 1453  A recent study shows that the virus can live i...  1454
# 1454  We do not know. Some viruses, like the common ...  1455
#
# [1455 rows x 5 columns]

# %%
# check faq_qa_pair_df
faq_qa_pair_df
# Out:
#     label query_type                                           question  \
# 0       1        faq                                 What is COVID-19?
# 1       1        faq                             What is a coronavirus?
# 2       1        faq  Any advice about how to minimize risk during g...
# 3       1        faq                     Why do I have to stay at home?
# 4       1        faq  What is social distancing and how does it help...
# 5       1        faq                      Where did COVID-19 come from?
# 6       1        faq                 What are the symptoms of COVID-19?
# 7       1        faq  Should I be wearing a face mask to prevent me ...
# 8       1        faq                         Should I wear a face mask?
# 9       1        faq  Should the general population wear masks to pr...
# 10      1        faq                                  What is SARS-CoV?
# 11      1        faq                          How does COVID-19 spread?
# 12      1        faq                   Should I be tested for COVID-19?
# 13      1        faq               Where can I get tested for COVID-19?
# 14      1        faq  What types of cleaning products should I use t...
# 15      1        faq            How long do people have to isolate for?
# 16      1        faq                What is the treatment for COVID-19?
# 17      1        faq                             What caused COVID-19?
# 18      1        faq   Has anyone gotten infected in the United States?
# 19      1        faq  Who is at a higher risk of serious illness and...
# 20      1        faq                         Why is it called COVID-19?
# 21      1        faq                  How many Covid19 cases are there?
# 22      1        faq  How many Covid19 cases have been reported in m...
# 23      1        faq  How long does the virus live on surfaces, like...
# 24      1        faq  What is the current advice if I am planning to...
# 25      1        faq  Can my pet or other animals get sick from COVI...
# 26      1        faq          Can COVID-19 be transmitted through food?
# 27      1        faq  Can COVID-19 be spread through food (including...
# 28      1        faq               How can I protect myself and others?
# 29      1        faq  Will warm weather / summer / heat stop outbrea...
# 30      1        faq  Is COVID-19 contagious? Can someone who has it...
# 31      1        faq            Can my dog/cat/pet/animal get COVID-19?
# 32      1        faq  Can I get COVID-19 from animals when travellin...
# 33      1        faq                                  What is MERS-CoV?
# 34      1        faq  Do viruses get weaker over time? Will coronavi...
# 35      1        faq  I have read that CV is able to be contracted t...
# 36      1        faq  Does chloroquine and/or hydroxychloroquine tre...
# 37      1        faq           What does socially distancing even mean?
# 38      1        faq          How can I protect my child from COVID-19?
# 39      1        faq  Can COVID-19 be transmitted when a person is n...
# 40      1        faq         I'm pregnant... am I at risk for COVID-19?
# 41      1        faq  It would be great to hear more about the sympt...
# 42      1        faq  Should I use soap and water or a hand sanitize...
# 43      1        faq                    What are N95 respirators/masks?
# 44      1        faq  What can I do to reduce my and my family's ris...
# 45      1        faq  Schools, daycare, university - they have all c...
# 46      1        faq  How long should we self quarantine before movi...
# 47      1        faq   What should I do if I just returned from a trip?
# 48      1        faq  Also, what to do if you have no access to sani...
# 49      1        faq     Am I at risk for COVID-19 in the United Staes?
# 50      1        faq    Are symptoms of COVID-19 different in children?
# 51      1        faq     Can we use fabric masks to prevent the spread?
# 52      1        faq  What is the difference between COVID-19 and SA...
# 53      1        faq  What is the difference between isolation and q...
# 54      1        faq  Are there any natural health products that can...
# 55      1        faq       What is personal protective equipment (PPE)?
# 56      1        faq  What should I do if there is an outbreak in my...
# 57      1        faq  I am pregnant, am I at a greater risk for more...
# 58      1        faq  should we quarantine our mail and packages for...
# 59      1        faq  There have been a lot of mixed messages about ...
# 60      1        faq                   What is novel (new) coronavirus?
# 61      1        faq         What is the COVID-19 situation in the U.S?
# 62      1        faq                      What is flattening the curve?
# 63      1        faq   Can COVID-19 be spread through surface-touching?
# 64      1        faq  How do I prepare my child for a COVID-19 outbr...
# 65      1        faq  What steps should parents take to protect chil...
# 66      1        faq  Why are schools closing down becasue of COVID-19?
# 67      1        faq  I have packages coming from China... am I at r...
#
#                                                answer  id
# 0   COVID-19 is a new coronavirus that we have not...   1
# 1   Coronavirus are a type of virus - there are ma...   2
# 2   Currently, there is no evidence of food or foo...   3
# 3   Socially distancing is a practice that aims to...   4
# 4   Social distancing is one of the most effective...   5
# 5   It was first found in Wuhan City, Hubei Provin...   6
# 6   Reported illnesses have ranged from mild sympt...   7
# 7   Masks are only helpful in preventing people wh...   8
# 8   You should only wear a face mask if a healthca...   9
# 9   If you are a healthy individual, the use of a ...  10
# 10  SARS is Severe Acute Respiratory Syndrome. It ...  11
# 11  It is able to spread person-to-person. The spr...  12
# 12  If you have developed symptoms like fever, cou...  13
# 13  If you have the symptoms of COVID-19 and want ...  14
# 14  For disinfecting purposes, most common EPA reg...  15
# 15  It depends, and is often decided on a case-by-...  16
# 16  Most people with mild coronavirus illness will...  17
# 17  There are many types of coronaviruses. Some on...  18
# 18  Yes, all states have reported COVID-19 infecti...  19
# 19  Older adults (people over the age of 65), thos...  20
# 20  COVID comes from corona (CO), virus (VI), and ...  21
# 21  This interactive map by the Johns Hopkins Univ...  22
# 22  This interactive map by the Johns Hopkins Univ...  23
# 23  A recent study shows that the virus can live i...  24
# 24  1. self-isolate for 14 days after returning fr...  25
# 25  There is currently no evidence to suggest that...  26
# 26  There is currently no evidence to suggest that...  27
# 27  Right now, our current understanding of how CO...  28
# 28  The best way to prevent illness from COVID-19 ...  29
# 29  We do not know. Some viruses, like the common ...  30
# 30  Yes. It is actively spreading person to person...  31
# 31  While this virus did emerge from an animal sou...  32
# 32  Although the current spread and growth of the ...  33
# 33  MERs is Middle East Respiratory Syndrome. It i...  34
# 34  They can, but it is not guaranteed; it depends...  35
# 35  COVID-19 is being spread through respiratory d...  36
# 36  It is currently unclear - scientists are curre...  37
# 37  It is avoiding crowds, mass gatherings, and ma...  38
# 38  By having them practice the same things you ha...  39
# 39  Experts believe that this is posisble, though ...  40
# 40  It does not look like pregnant women are more ...  41
# 41  The most common symptoms are fever, tiredness ...  42
# 42  Handwashing with soap and water for at least 2...  43
# 43  This is a type of personal protective equipmen...  44
# 44  It is important to daily practice actions that...  45
# 45  Talk to the schools and facilities about their...  46
# 46  You should quarantine yourself for at least 14...  47
# 47  If you do not have any symptoms, you will be a...  48
# 48  IF NO ACCESS TO HAND SANITIZER: wash your hand...  49
# 49  The risk assessment changes daily. Currently, ...  50
# 50  No. They have the same symptoms, though it may...  51
# 51  Face masks, including fabric ones, are only re...  52
# 52  SARS-CoV-2 refers to the virus that causes COV...  53
# 53  Isolation refers to separating people who are ...  54
# 54  At this time, there are no natural health prod...  55
# 55  Personal protective equipment (PPE) are types ...  56
# 56  It is important to stay calm and put your prep...  57
# 57  Throughout pregnancy, women experience changes...  58
# 58  The risk is quite low for one to become infect...  59
# 59  Currently, children are not at a higher risk o...  60
# 60  A novel, or new, coronavirus is one that has n...  61
# 61  All 50 states in the U.S., as well as D.C., Pu...  62
# 62  Flattening the curve refers to the use of soci...  63
# 63  It can be possible, as people can touch a surf...  64
# 64  It is important to talk with your child about ...  65
# 65  Remember - this is a new virus, and there is a...  66
# 66  School dismissals are a method that can help s...  67
# 67  There is so much that we do not know about COV...  68

# %%
# convert to list
faq_qa_pairs = list(faq_qa_pairs)

# %%
# check first 5 entries in faq_qa_pairs
faq_qa_pairs[:5]
# Out:
# [{'label': 1,
#   'query_type': 'faq',
#   'question': 'What is COVID-19? ',
#   'answer': 'COVID-19 is a new coronavirus that we have not seen previously; it is not the same as the flu or common cold. Coronaviruses are types of viruses that cause illnesses. These include the common cold, flu, to more severe diseases like Middle East Respiratory Syndrom (MERs-CoV) and Severe Acute Respiratory Syndrome (SARS-CoV).   [[Would you like to know more about COVID-19 symptoms?]]',
#   'id': '1'},
#  {'label': 1,
#   'query_type': 'faq',
#   'question': 'What is a coronavirus?',
#   'answer': 'Coronavirus are a type of virus - there are many kinds, and some of them can cause disease. Examples of coronaviruses include the common cold, flu, to more severe diseases like Middle East Respiratory Syndrome (MERS-CoV) and Severe Acute Respiratory Syndrome (SARS-CoV).   COVID19 is a novel coronavirus that has been recently identified.   [[Would you like more information on COVID19?]] [[Would you like to know the symptoms of COVID19?]]    ',
#   'id': '2'},
#  {'label': 1,
#   'query_type': 'faq',
#   'question': 'Any advice about how to minimize risk during grocery shopping trips or getting takeout.',
#   'answer': 'Currently, there is no evidence of food or food packaging being associated with transmission of COVID-19. Like other viruses, it is possible that the virus that causes COVID-19 can survive on surfaces or objects. For that reason, it is critical to wash your hands often, including utensils. Currently, there is no evidence of food or food packaging being associated with transmission of COVID-19. However, the virus that causes COVID-19 is spreading from person-to-person in some communities in the U.S. The CDC recommends that if you are sick, stay home until you are better and no longer pose a risk of infecting others. Anyone handling, preparing and serving food should always follow safe food handling procedures, such as washing hands and surfaces often.',
#   'id': '3'},
#  {'label': 1,
#   'query_type': 'faq',
#   'question': 'Why do I have to stay at home?',
#   'answer': 'Socially distancing is a practice that aims to prevent those who are sick from coming into contact with those who are healthy. This is to reduce the opportunity for disease transmission. As COVID-19 spreads person-to-person in close contact, we want to reduce the chance of infection amongst populations that are vulnerable. This includes older adults (over the age of 65) and those with suppressed immune systems. It is also to help reduce the burden on healthcar esystems and workers, as there are not enough workers and beds to care for patients if everyone were to have COVID-19 at the same time.',
#   'id': '4'},
#  {'label': 1,
#   'query_type': 'faq',
#   'question': 'What is social distancing and how does it help to minimize COVID-19?',
#   'answer': 'Social distancing is one of the most effective ways to reduce the spread of illness during an outbreak, but it is sometimes hard to understand what this means given the vague language. What it means is to stay at home as much as possible, and limit your outside exposure. This does mean meaking changes to your everyday routine to minimize contacts with others, including:   avoiding non-essential gatherings avoiding common greetings, such as handshakes avoiding crowded places such as concerts, arenas, conferences and festivals limiting contact with people at higher risk like older adults and those in poor health keeping a distance of at least 2 arms-length (approximately 6 feet) from others  For example - if you need to go grocery shopping, limit to once a week. If you go on walks, make sure you maintain a 6 foot distance between yourself and others.',
#   'id': '5'}]

# %%
try:
    
    es = connections.create_connection(hosts=['localhost'], )
    
    # Index data to Elasticsearch 
    index_name = "covidfaq"
    
    # Initialize index (only perform once)
    index = Index(index_name)

    # Define custom settings
    index.settings(
        number_of_shards=1,
        number_of_replicas=0
    )

    # Delete the index, ignore if it doesn't exist
    index.delete(ignore=404)

    # Create the index in Elasticsearch
    index.create()

    # Register a document with the index
    index.document(QA)

    # Ingest data to Elasticsearch
    ingest_data(faq_qa_pairs, es=es, index=index_name)

    print("Finished indexing {} records to {} index".format(len(faq_qa_pairs), index_name))

except Exception:
    logging.error('exception occured', exc_info=True)
# Out:
# ERROR:root:exception occured
# Traceback (most recent call last):
#   File "<ipython-input-9-a3a5acdd897e>", line 18, in <module>
#     index.delete(ignore=404)
#   File "/Users/nattiya/miniconda3/envs/dl/lib/python3.8/site-packages/elasticsearch_dsl/index.py", line 405, in delete
#     return self._get_connection(using).indices.delete(index=self._name, **kwargs)
#   File "/Users/nattiya/miniconda3/envs/dl/lib/python3.8/site-packages/elasticsearch/client/utils.py", line 152, in _wrapped
#     return func(*args, params=params, headers=headers, **kwargs)
#   File "/Users/nattiya/miniconda3/envs/dl/lib/python3.8/site-packages/elasticsearch/client/indices.py", line 285, in delete
#     return self.transport.perform_request(
#   File "/Users/nattiya/miniconda3/envs/dl/lib/python3.8/site-packages/elasticsearch/transport.py", line 392, in perform_request
#     raise e
#   File "/Users/nattiya/miniconda3/envs/dl/lib/python3.8/site-packages/elasticsearch/transport.py", line 358, in perform_request
#     status, headers_response, data = connection.perform_request(
#   File "/Users/nattiya/miniconda3/envs/dl/lib/python3.8/site-packages/elasticsearch/connection/http_urllib3.py", line 269, in perform_request
#     self._raise_error(response.status, raw_data)
#   File "/Users/nattiya/miniconda3/envs/dl/lib/python3.8/site-packages/elasticsearch/connection/base.py", line 300, in _raise_error
#     raise HTTP_EXCEPTIONS.get(status_code, TransportError)(
# elasticsearch.exceptions.AuthenticationException: AuthenticationException(401, 'security_exception', 'missing authentication credentials for REST request [/covidfaq]')
