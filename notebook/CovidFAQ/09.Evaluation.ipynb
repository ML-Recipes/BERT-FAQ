# %%
# import required libraries
import sys
sys.path.insert(0, '../../../BERT-FAQ/')

from evaluation import Evaluation

# %%
rank_results_filepath="../../../BERT-FAQ/data/CovidFAQ/rank_results"

ev = Evaluation()
df = ev.get_eval_df(rank_results_filepath)

# %%
df
# Out:
#           Method          Matching Field Ranking Field     Loss Training Data  \
# 0   Unsupervised                  answer
# 1   Unsupervised                question
# 2   Unsupervised         question_answer
# 3   Unsupervised  question_answer_concat
# 4     Supervised                  answer      BERT-Q-a  triplet           faq
# 5     Supervised                question      BERT-Q-a  triplet           faq
# 6     Supervised         question_answer      BERT-Q-a  triplet           faq
# 7     Supervised  question_answer_concat      BERT-Q-a  triplet           faq
# 8     Supervised                  answer      BERT-Q-a  triplet           faq
# 9     Supervised                question      BERT-Q-a  triplet           faq
# 10    Supervised         question_answer      BERT-Q-a  triplet           faq
# 11    Supervised  question_answer_concat      BERT-Q-a  triplet           faq
# 12    Supervised                  answer      BERT-Q-a  triplet    user_query
# 13    Supervised                question      BERT-Q-a  triplet    user_query
# 14    Supervised         question_answer      BERT-Q-a  triplet    user_query
# 15    Supervised  question_answer_concat      BERT-Q-a  triplet    user_query
# 16    Supervised                  answer      BERT-Q-a  triplet    user_query
# 17    Supervised                question      BERT-Q-a  triplet    user_query
# 18    Supervised         question_answer      BERT-Q-a  triplet    user_query
# 19    Supervised  question_answer_concat      BERT-Q-a  triplet    user_query
# 20    Supervised                  answer      BERT-Q-a  softmax           faq
# 21    Supervised                question      BERT-Q-a  softmax           faq
# 22    Supervised         question_answer      BERT-Q-a  softmax           faq
# 23    Supervised  question_answer_concat      BERT-Q-a  softmax           faq
# 24    Supervised                  answer      BERT-Q-a  softmax           faq
# 25    Supervised                question      BERT-Q-a  softmax           faq
# 26    Supervised         question_answer      BERT-Q-a  softmax           faq
# 27    Supervised  question_answer_concat      BERT-Q-a  softmax           faq
# 28    Supervised                  answer      BERT-Q-a  softmax    user_query
# 29    Supervised                question      BERT-Q-a  softmax    user_query
# 30    Supervised         question_answer      BERT-Q-a  softmax    user_query
# 31    Supervised  question_answer_concat      BERT-Q-a  softmax    user_query
# 32    Supervised                  answer      BERT-Q-a  softmax    user_query
# 33    Supervised                question      BERT-Q-a  softmax    user_query
# 34    Supervised         question_answer      BERT-Q-a  softmax    user_query
# 35    Supervised  question_answer_concat      BERT-Q-a  softmax    user_query
# 36    Supervised                  answer      BERT-Q-q  triplet           faq
# 37    Supervised                question      BERT-Q-q  triplet           faq
# 38    Supervised         question_answer      BERT-Q-q  triplet           faq
# 39    Supervised  question_answer_concat      BERT-Q-q  triplet           faq
# 40    Supervised                  answer      BERT-Q-q  triplet           faq
# 41    Supervised                question      BERT-Q-q  triplet           faq
# 42    Supervised         question_answer      BERT-Q-q  triplet           faq
# 43    Supervised  question_answer_concat      BERT-Q-q  triplet           faq
# 44    Supervised                  answer      BERT-Q-q  triplet    user_query
# 45    Supervised                question      BERT-Q-q  triplet    user_query
# 46    Supervised         question_answer      BERT-Q-q  triplet    user_query
# 47    Supervised  question_answer_concat      BERT-Q-q  triplet    user_query
# 48    Supervised                  answer      BERT-Q-q  triplet    user_query
# 49    Supervised                question      BERT-Q-q  triplet    user_query
# 50    Supervised         question_answer      BERT-Q-q  triplet    user_query
# 51    Supervised  question_answer_concat      BERT-Q-q  triplet    user_query
# 52    Supervised                  answer      BERT-Q-q  softmax           faq
# 53    Supervised                question      BERT-Q-q  softmax           faq
# 54    Supervised         question_answer      BERT-Q-q  softmax           faq
# 55    Supervised  question_answer_concat      BERT-Q-q  softmax           faq
# 56    Supervised                  answer      BERT-Q-q  softmax           faq
# 57    Supervised                question      BERT-Q-q  softmax           faq
# 58    Supervised         question_answer      BERT-Q-q  softmax           faq
# 59    Supervised  question_answer_concat      BERT-Q-q  softmax           faq
# 60    Supervised                  answer      BERT-Q-q  softmax    user_query
# 61    Supervised                question      BERT-Q-q  softmax    user_query
# 62    Supervised         question_answer      BERT-Q-q  softmax    user_query
# 63    Supervised  question_answer_concat      BERT-Q-q  softmax    user_query
# 64    Supervised                  answer      BERT-Q-q  softmax    user_query
# 65    Supervised                question      BERT-Q-q  softmax    user_query
# 66    Supervised         question_answer      BERT-Q-q  softmax    user_query
# 67    Supervised  question_answer_concat      BERT-Q-q  softmax    user_query
#
#    Negative Sampling  NDCG@3  NDCG@5 NDCG@10     P@3     P@5    P@10     MAP
# 0                     0.2536  0.1221  0.2940  0.0985  0.3466  0.0730  0.2846
# 1                     0.7844  0.3451  0.8104  0.2286  0.8147  0.1324  0.7422
# 2                     0.6976  0.3080  0.7246  0.2046  0.7465  0.1154  0.6604
# 3                     0.5756  0.2588  0.6067  0.1846  0.6392  0.1073  0.5705
# 4             simple  0.3086  0.1515  0.3437  0.1154  0.4021  0.0843  0.3241
# 5             simple  0.7939  0.3500  0.8179  0.2299  0.8234  0.1332  0.7602
# 6             simple  0.7116  0.3129  0.7387  0.2098  0.7612  0.1168  0.6800
# 7             simple  0.6050  0.2709  0.6350  0.1904  0.6757  0.1142  0.6028
# 8               hard  0.3112  0.1515  0.3455  0.1147  0.4079  0.0856  0.3280
# 9               hard  0.7947  0.3519  0.8180  0.2304  0.8229  0.1338  0.7599
# 10              hard  0.7100  0.3145  0.7364  0.2080  0.7611  0.1178  0.6761
# 11              hard  0.6079  0.2696  0.6405  0.1918  0.6793  0.1138  0.6076
# 12            simple  0.3169  0.1552  0.3624  0.1228  0.4218  0.0891  0.3378
# 13            simple  0.8237  0.3612  0.8425  0.2355  0.8446  0.1354  0.7879
# 14            simple  0.7461  0.3268  0.7738  0.2191  0.7938  0.1201  0.7142
# 15            simple  0.6268  0.2842  0.6570  0.1968  0.6960  0.1167  0.6232
# 16              hard  0.3288  0.1623  0.3739  0.1273  0.4306  0.0902  0.3461
# 17              hard  0.8312  0.3627  0.8502  0.2360  0.8522  0.1360  0.7966
# 18              hard  0.7540  0.3284  0.7800  0.2204  0.8003  0.1215  0.7215
# 19              hard  0.6486  0.2947  0.6708  0.1996  0.7080  0.1172  0.6367
# 20            simple  0.2626  0.1280  0.2958  0.0991  0.3472  0.0730  0.2860
# 21            simple  0.7832  0.3358  0.8091  0.2258  0.8140  0.1321  0.7460
# 22            simple  0.6959  0.3071  0.7242  0.2046  0.7461  0.1154  0.6607
# 23            simple  0.5762  0.2585  0.6079  0.1846  0.6404  0.1073  0.5739
# 24              hard  0.2711  0.1323  0.3048  0.1020  0.3531  0.0734  0.2920
# 25              hard  0.7866  0.3457  0.8147  0.2290  0.8188  0.1324  0.7537
# 26              hard  0.6976  0.3077  0.7265  0.2054  0.7478  0.1154  0.6632
# 27              hard  0.5877  0.2600  0.6180  0.1848  0.6502  0.1073  0.5871
# 28            simple  0.2811  0.1354  0.3188  0.1063  0.3770  0.0782  0.3104
# 29            simple  0.8047  0.3442  0.8283  0.2291  0.8320  0.1322  0.7704
# 30            simple  0.7193  0.3139  0.7453  0.2072  0.7675  0.1166  0.6859
# 31            simple  0.5914  0.2659  0.6223  0.1889  0.6511  0.1079  0.5863
# 32              hard  0.3265  0.1596  0.3715  0.1250  0.4247  0.0880  0.3444
# 33              hard  0.8262  0.3615  0.8442  0.2343  0.8472  0.1353  0.7906
# 34              hard  0.7480  0.3265  0.7758  0.2191  0.7960  0.1202  0.7172
# 35              hard  0.6423  0.2900  0.6663  0.1968  0.7041  0.1159  0.6349
# 36            simple  0.2536  0.1221  0.2940  0.0985  0.3466  0.0730  0.2846
# 37            simple  0.7844  0.3451  0.8104  0.2286  0.8147  0.1324  0.7422
# 38            simple  0.6976  0.3080  0.7246  0.2046  0.7465  0.1154  0.6604
# 39            simple  0.5756  0.2588  0.6067  0.1846  0.6392  0.1073  0.5705
# 40              hard  0.2536  0.1221  0.2940  0.0985  0.3466  0.0730  0.2846
# 41              hard  0.7844  0.3451  0.8104  0.2286  0.8147  0.1324  0.7422
# 42              hard  0.6976  0.3080  0.7246  0.2046  0.7465  0.1154  0.6604
# 43              hard  0.5756  0.2588  0.6067  0.1846  0.6392  0.1073  0.5705
# 44            simple  0.2536  0.1221  0.2940  0.0985  0.3466  0.0730  0.2846
# 45            simple  0.7844  0.3451  0.8104  0.2286  0.8147  0.1324  0.7422
# 46            simple  0.6976  0.3080  0.7246  0.2046  0.7465  0.1154  0.6604
# 47            simple  0.5756  0.2588  0.6067  0.1846  0.6392  0.1073  0.5705
# 48              hard  0.2536  0.1221  0.2940  0.0985  0.3466  0.0730  0.2846
# 49              hard  0.7844  0.3451  0.8104  0.2286  0.8147  0.1324  0.7422
# 50              hard  0.6976  0.3080  0.7246  0.2046  0.7465  0.1154  0.6604
# 51              hard  0.5756  0.2588  0.6067  0.1846  0.6392  0.1073  0.5705
# 52            simple  0.2536  0.1221  0.2940  0.0985  0.3466  0.0730  0.2846
# 53            simple  0.7844  0.3451  0.8104  0.2286  0.8147  0.1324  0.7422
# 54            simple  0.6976  0.3080  0.7246  0.2046  0.7465  0.1154  0.6604
# 55            simple  0.5756  0.2588  0.6067  0.1846  0.6392  0.1073  0.5705
# 56              hard  0.2536  0.1221  0.2940  0.0985  0.3466  0.0730  0.2846
# 57              hard  0.7844  0.3451  0.8104  0.2286  0.8147  0.1324  0.7422
# 58              hard  0.6976  0.3080  0.7246  0.2046  0.7465  0.1154  0.6604
# 59              hard  0.5756  0.2588  0.6067  0.1846  0.6392  0.1073  0.5705
# 60            simple  0.2536  0.1221  0.2940  0.0985  0.3466  0.0730  0.2846
# 61            simple  0.7844  0.3451  0.8104  0.2286  0.8147  0.1324  0.7422
# 62            simple  0.6976  0.3080  0.7246  0.2046  0.7465  0.1154  0.6604
# 63            simple  0.5756  0.2588  0.6067  0.1846  0.6392  0.1073  0.5705
# 64              hard  0.2536  0.1221  0.2940  0.0985  0.3466  0.0730  0.2846
# 65              hard  0.7844  0.3451  0.8104  0.2286  0.8147  0.1324  0.7422
# 66              hard  0.6976  0.3080  0.7246  0.2046  0.7465  0.1154  0.6604
# 67              hard  0.5756  0.2588  0.6067  0.1846  0.6392  0.1073  0.5705
